# %% [markdown]
# # Evolving a Lunar Lander with differentiable Genetic Programming

# %% [markdown]
# ## Installation
# To install the required libraries run the command:

# %%
# %%capture --no-display
# %pip install -r requirements.txt

# %% [markdown]
# ## Imports
# Imports from the standard genepro-multi library are done here. Any adjustments (e.g. different operators) should be made in the notebook.

# %%
import gymnasium as gym

from genepro.node_impl import *
from genepro.evo import Evolution
from genepro.node_impl import Constant

import torch
import torch.optim as optim

import random
import os
import copy
from collections import namedtuple, deque

import matplotlib.pyplot as plt
from matplotlib import animation

# %% [markdown]
# ## Reinforcement Learning Setup
# Here we first setup the Gymnasium environment. Please see https://gymnasium.farama.org/environments/box2d/lunar_lander/ for more information on the environment.
#
# Then a memory buffer is made. This is a buffer in which state transitions are stored. When the buffer reaches its maximum capacity old transitions are replaced by new ones.
#
# A frame buffer is initialised used to later store animation frames of the environment.

# %%
env = gym.make("LunarLander-v2", render_mode="rgb_array")

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

    def __iadd__(self, other):
      self.memory += other.memory
      return self 

    def __add__(self, other):
      self.memory = self.memory + other.memory 
      return self

# %%
frames = []

# %% [markdown]
# ## Fitness Function
#
# Here you get to be creative. The default setup evaluates 5 episodes of 300 frames. Think of what action to pick and what fitness function to use. The Multi-tree takes an input of $n \times d$ where $n$ is a batch of size 1.

# %%
def fitness_function_pt(multitree, generation, num_episodes=5, episode_duration=300, render=False, ignore_done=False):
  memory = ReplayMemory(10000)
  rewards = []

  for i in range(num_episodes):
    # get initial state of the environment
    observation = env.reset(seed=(generation*1000 + i))
    observation = observation[0]
    
    for _ in range(episode_duration):
      if render:
        frames.append(env.render())

      input_sample = torch.from_numpy(observation.reshape((1,-1))).float()
      
      action = torch.argmax(multitree.get_output_pt(input_sample))
      observation, reward, terminated, truncated, info = env.step(action.item())
      rewards.append(reward)
      output_sample = torch.from_numpy(observation.reshape((1,-1))).float()
      memory.push(input_sample, torch.tensor([[action.item()]]), output_sample, torch.tensor([reward]))
      if (terminated or truncated) and not ignore_done:
        break

  fitness = np.sum(rewards)/num_episodes
  return fitness, memory

# %% [markdown]
# ## Evolution Setup & Evolve
# Here the leaf and internal nodes are defined. Think about the odds of sampling a constant in this default configurations. Also think about any operators that could be useful and add them here.
#
# Adjust the population size (multiple of 8 if you want to use the standard tournament selection), max generations and max tree size to taste. Be aware that each of these settings can increase the runtime.

# %%
np.random.seed(42)

num_features = env.observation_space.shape[0]
leaf_nodes = [Feature(i) for i in range(num_features)] + [Constant() for _ in range(1)]
internal_nodes = [Plus(), Minus(), Times(), Div(), Square(), Sqrt(), Log(), Sin(), Cos(), Max(), Min()] #Add your own operators here

# Run a few times to collect Data
for i in range(5):
  print(f"------ Evolution {i} ------")
  
  evo = Evolution(
    fitness_function_pt, internal_nodes, leaf_nodes,
    4,
    pop_size= 256,
    max_gens=50,
    max_tree_size=31,
    n_jobs=20,
    enable={"elite-archive": True},
    log_data=True,
    verbose=True)
  
  evo.evolve()
# Out:
# ------ Evolution 0 ------
# Generation: 1
# 	Best - 	Fitness: -76.483, Size: 16
# 	Population - 	Average Fitness: -255.87805401607048
# 	mean = -255.88, 	median = -129.21, 	best_median = -129.21
#
# Generation: 2
# 	Best - 	Fitness: -92.804, Size: 23
# 	Population - 	Average Fitness: -254.6180198950094
# 	mean = -254.62, 	median = -145.43, 	best_median = -129.21
#
# Generation: 3
# 	Best - 	Fitness: -86.962, Size: 24
# 	Population - 	Average Fitness: -195.41289759838975
# 	mean = -195.41, 	median = -144.55, 	best_median = -129.21
#
# Generation: 4
# 	Best - 	Fitness: -89.626, Size: 30
# 	Population - 	Average Fitness: -228.82439282294118
# 	mean = -228.82, 	median = -158.33, 	best_median = -129.21
#
# Generation: 5
# 	Best - 	Fitness: -33.972, Size: 23
# 	Population - 	Average Fitness: -183.54055035676285
# 	mean = -183.54, 	median = -116.11, 	best_median = -116.11
#
# Generation: 6
# 	Best - 	Fitness: -34.619, Size: 24
# 	Population - 	Average Fitness: -197.82658974872373
# 	mean = -197.83, 	median = -111.81, 	best_median = -111.81
#
# Generation: 7
# 	Best - 	Fitness: -41.350, Size: 24
# 	Population - 	Average Fitness: -181.09884184453108
# 	mean = -181.10, 	median = -115.58, 	best_median = -111.81
#
# Generation: 8
# 	Best - 	Fitness: -27.190, Size: 24
# 	Population - 	Average Fitness: -180.9226742082832
# 	mean = -180.92, 	median = -110.93, 	best_median = -110.93
#
# Generation: 9
# 	Best - 	Fitness: -18.222, Size: 24
# 	Population - 	Average Fitness: -130.5027825484772
# 	mean = -130.50, 	median = -44.28, 	best_median = -44.28
#
# Generation: 10
# 	Best - 	Fitness: 31.636, Size: 25
# 	Population - 	Average Fitness: -149.1116447219874
# 	mean = -149.11, 	median = -67.49, 	best_median = -44.28
#
# Generation: 11
# 	Best - 	Fitness: 11.637, Size: 20
# 	Population - 	Average Fitness: -141.5840708469773
# 	mean = -141.58, 	median = -39.08, 	best_median = -39.08
#
# Generation: 12
# 	Best - 	Fitness: 31.611, Size: 30
# 	Population - 	Average Fitness: -131.7900969852951
# 	mean = -131.79, 	median = -17.11, 	best_median = -17.11
#
# Generation: 13
# 	Best - 	Fitness: 19.837, Size: 31
# 	Population - 	Average Fitness: -162.84859836642005
# 	mean = -162.85, 	median = -47.90, 	best_median = -17.11
#
# Generation: 14
# 	Best - 	Fitness: 7.157, Size: 31
# 	Population - 	Average Fitness: -116.75556296669896
# 	mean = -116.76, 	median = -19.47, 	best_median = -17.11
#
# Generation: 15
# 	Best - 	Fitness: 16.382, Size: 24
# 	Population - 	Average Fitness: -128.8629528979483
# 	mean = -128.86, 	median = -29.14, 	best_median = -17.11
#
# Generation: 16
# 	Best - 	Fitness: 70.232, Size: 31
# 	Population - 	Average Fitness: -113.96575176670905
# 	mean = -113.97, 	median = -13.22, 	best_median = -13.22
#
# Generation: 17
# 	Best - 	Fitness: 15.509, Size: 29
# 	Population - 	Average Fitness: -161.99972578299597
# 	mean = -162.00, 	median = -30.35, 	best_median = -13.22
#
# Generation: 18
# 	Best - 	Fitness: 69.181, Size: 26
# 	Population - 	Average Fitness: -135.16587341422476
# 	mean = -135.17, 	median = -19.14, 	best_median = -13.22
#
# Generation: 19
# 	Best - 	Fitness: 54.399, Size: 26
# 	Population - 	Average Fitness: -148.3706879564777
# 	mean = -148.37, 	median = -63.12, 	best_median = -13.22
#
# Generation: 20
# 	Best - 	Fitness: 91.070, Size: 31
# 	Population - 	Average Fitness: -110.30318872688375
# 	mean = -110.30, 	median = -13.48, 	best_median = -13.22
#
# Generation: 21
# 	Best - 	Fitness: 49.105, Size: 27
# 	Population - 	Average Fitness: -128.98444956133164
# 	mean = -128.98, 	median = -55.17, 	best_median = -13.22
#
# Generation: 22
# 	Best - 	Fitness: 93.965, Size: 26
# 	Population - 	Average Fitness: -147.29184391915717
# 	mean = -147.29, 	median = -31.88, 	best_median = -13.22
#
# Generation: 23
# 	Best - 	Fitness: 87.052, Size: 26
# 	Population - 	Average Fitness: -122.01178565877967
# 	mean = -122.01, 	median = -29.82, 	best_median = -13.22
#
# Generation: 24
# 	Best - 	Fitness: 47.933, Size: 30
# 	Population - 	Average Fitness: -139.57486959702837
# 	mean = -139.57, 	median = 4.46, 	best_median = 4.46
#
# Generation: 25
# 	Best - 	Fitness: 92.428, Size: 26
# 	Population - 	Average Fitness: -118.6585333141376
# 	mean = -118.66, 	median = 16.70, 	best_median = 16.70
#
# Generation: 26
# 	Best - 	Fitness: 76.226, Size: 19
# 	Population - 	Average Fitness: -147.26985180330988
# 	mean = -147.27, 	median = -21.53, 	best_median = 16.70
#
# Generation: 27
# 	Best - 	Fitness: 109.132, Size: 26
# 	Population - 	Average Fitness: -121.7156043340475
# 	mean = -121.72, 	median = -14.84, 	best_median = 16.70
#
# Generation: 28
# 	Best - 	Fitness: 127.843, Size: 21
# 	Population - 	Average Fitness: -106.89286975619171
# 	mean = -106.89, 	median = 19.87, 	best_median = 19.87
#
# Generation: 29
# 	Best - 	Fitness: 129.600, Size: 26
# 	Population - 	Average Fitness: -165.69791707201472
# 	mean = -165.70, 	median = -71.54, 	best_median = 19.87
#
# Generation: 30
# 	Best - 	Fitness: 86.513, Size: 21
# 	Population - 	Average Fitness: -158.97927189716376
# 	mean = -158.98, 	median = -112.05, 	best_median = 19.87
#
# Generation: 31
# 	Best - 	Fitness: 122.903, Size: 26
# 	Population - 	Average Fitness: -133.19068124753326
# 	mean = -133.19, 	median = 5.41, 	best_median = 19.87
#
# Generation: 32
# 	Best - 	Fitness: 135.330, Size: 21
# 	Population - 	Average Fitness: -125.3761578315127
# 	mean = -125.38, 	median = 0.41, 	best_median = 19.87
#
# Generation: 33
# 	Best - 	Fitness: 96.239, Size: 27
# 	Population - 	Average Fitness: -170.78249632288245
# 	mean = -170.78, 	median = 18.24, 	best_median = 19.87
#
# Generation: 34
# 	Best - 	Fitness: 138.241, Size: 24
# 	Population - 	Average Fitness: -100.40229394504145
# 	mean = -100.40, 	median = 42.26, 	best_median = 42.26
#
# Generation: 35
# 	Best - 	Fitness: 122.465, Size: 28
# 	Population - 	Average Fitness: -86.30953357857969
# 	mean = -86.31, 	median = 36.74, 	best_median = 42.26
#
# Generation: 36
# 	Best - 	Fitness: 81.211, Size: 24
# 	Population - 	Average Fitness: -108.7459626960028
# 	mean = -108.75, 	median = 24.50, 	best_median = 42.26
#
# Generation: 37
# 	Best - 	Fitness: 112.897, Size: 25
# 	Population - 	Average Fitness: -136.6871515835345
# 	mean = -136.69, 	median = -36.65, 	best_median = 42.26
#
# Generation: 38
# 	Best - 	Fitness: 176.763, Size: 21
# 	Population - 	Average Fitness: -85.76010259610968
# 	mean = -85.76, 	median = 28.02, 	best_median = 42.26
#
# Generation: 39
# 	Best - 	Fitness: 113.455, Size: 20
# 	Population - 	Average Fitness: -100.47899679867842
# 	mean = -100.48, 	median = 30.13, 	best_median = 42.26
#
# Generation: 40
# 	Best - 	Fitness: 114.634, Size: 29
# 	Population - 	Average Fitness: -214.7125985038754
# 	mean = -214.71, 	median = -7.62, 	best_median = 42.26
#
# Generation: 41
# 	Best - 	Fitness: 139.003, Size: 30
# 	Population - 	Average Fitness: -85.89900317403234
# 	mean = -85.90, 	median = 47.24, 	best_median = 47.24
#
# Generation: 42
# 	Best - 	Fitness: 147.561, Size: 22
# 	Population - 	Average Fitness: -77.59941173620261
# 	mean = -77.60, 	median = 59.24, 	best_median = 59.24
#
# Generation: 43
# 	Best - 	Fitness: 117.904, Size: 28
# 	Population - 	Average Fitness: -108.8162006950986
# 	mean = -108.82, 	median = -0.78, 	best_median = 59.24
#
# Generation: 44
# 	Best - 	Fitness: 165.500, Size: 30
# 	Population - 	Average Fitness: -106.20651527931099
# 	mean = -106.21, 	median = 5.79, 	best_median = 59.24
#
# Generation: 45
# 	Best - 	Fitness: 130.732, Size: 28
# 	Population - 	Average Fitness: -87.30642692033966
# 	mean = -87.31, 	median = 28.34, 	best_median = 59.24
#
# Generation: 46
# 	Best - 	Fitness: 173.363, Size: 30
# 	Population - 	Average Fitness: -73.25134531699278
# 	mean = -73.25, 	median = 16.15, 	best_median = 59.24
#
# Generation: 47
# 	Best - 	Fitness: 169.798, Size: 30
# 	Population - 	Average Fitness: -59.93184680330166
# 	mean = -59.93, 	median = 62.98, 	best_median = 62.98
# /home/ariel/University/master/4th-quarter_2023S/evolutionary-algorithms/project-impl-2/env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Generation: 48
# 	Best - 	Fitness: 242.501, Size: 28
# 	Population - 	Average Fitness: -32.02212566662999
# 	mean = -32.02, 	median = 80.75, 	best_median = 80.75
#
# Generation: 49
# 	Best - 	Fitness: 168.266, Size: 28
# 	Population - 	Average Fitness: -45.023042161065035
# 	mean = -45.02, 	median = 109.38, 	best_median = 109.38
#
# Generation: 50
# 	Best - 	Fitness: 150.393, Size: 22
# 	Population - 	Average Fitness: -65.19833743442017
# 	mean = -65.20, 	median = 93.90, 	best_median = 109.38
#
# ------ Evolution 1 ------
# Generation: 1
# 	Best - 	Fitness: 83.422, Size: 23
# 	Population - 	Average Fitness: -221.40383676013712
# 	mean = -221.40, 	median = -129.02, 	best_median = -129.02
#
# Generation: 2
# 	Best - 	Fitness: -69.853, Size: 18
# 	Population - 	Average Fitness: -196.31647266678243
# 	mean = -196.32, 	median = -134.22, 	best_median = -129.02
#
# Generation: 3
# 	Best - 	Fitness: -30.506, Size: 18
# 	Population - 	Average Fitness: -168.189637677961
# 	mean = -168.19, 	median = -131.29, 	best_median = -129.02
#
# Generation: 4
# 	Best - 	Fitness: -46.044, Size: 18
# 	Population - 	Average Fitness: -186.35547207355907
# 	mean = -186.36, 	median = -132.65, 	best_median = -129.02
#
# Generation: 5
# 	Best - 	Fitness: -27.385, Size: 18
# 	Population - 	Average Fitness: -137.31113779734565
# 	mean = -137.31, 	median = -105.03, 	best_median = -105.03
#
# Generation: 6
# 	Best - 	Fitness: 2.391, Size: 13
# 	Population - 	Average Fitness: -175.0296204835066
# 	mean = -175.03, 	median = -62.50, 	best_median = -62.50
#
# Generation: 7
# 	Best - 	Fitness: -13.405, Size: 21
# 	Population - 	Average Fitness: -157.46453960582286
# 	mean = -157.46, 	median = -59.10, 	best_median = -59.10
#
# Generation: 8
# 	Best - 	Fitness: -25.604, Size: 30
# 	Population - 	Average Fitness: -137.1257691449466
# 	mean = -137.13, 	median = -64.79, 	best_median = -59.10
#
# Generation: 9
# 	Best - 	Fitness: 9.719, Size: 13
# 	Population - 	Average Fitness: -122.30411247302004
# 	mean = -122.30, 	median = -44.16, 	best_median = -44.16
#
# Generation: 10
# 	Best - 	Fitness: -22.485, Size: 13
# 	Population - 	Average Fitness: -155.95967815713772
# 	mean = -155.96, 	median = -65.63, 	best_median = -44.16
#
# Generation: 11
# 	Best - 	Fitness: -16.197, Size: 15
# 	Population - 	Average Fitness: -150.52589355612093
# 	mean = -150.53, 	median = -37.04, 	best_median = -37.04
#
# Generation: 12
# 	Best - 	Fitness: 7.054, Size: 29
# 	Population - 	Average Fitness: -139.61333566902692
# 	mean = -139.61, 	median = -13.78, 	best_median = -13.78
#
# Generation: 13
# 	Best - 	Fitness: -11.139, Size: 27
# 	Population - 	Average Fitness: -168.8495189076473
# 	mean = -168.85, 	median = -38.57, 	best_median = -13.78
#
# Generation: 14
# 	Best - 	Fitness: -11.855, Size: 27
# 	Population - 	Average Fitness: -122.27955586457442
# 	mean = -122.28, 	median = -30.41, 	best_median = -13.78
#
# Generation: 15
# 	Best - 	Fitness: -11.144, Size: 15
# 	Population - 	Average Fitness: -163.57426137372377
# 	mean = -163.57, 	median = -40.15, 	best_median = -13.78
#
# Generation: 16
# 	Best - 	Fitness: 92.009, Size: 27
# 	Population - 	Average Fitness: -107.81506795088367
# 	mean = -107.82, 	median = -32.92, 	best_median = -13.78
#
# Generation: 17
# 	Best - 	Fitness: 48.524, Size: 28
# 	Population - 	Average Fitness: -126.72139856233173
# 	mean = -126.72, 	median = -48.17, 	best_median = -13.78
#
# Generation: 18
# 	Best - 	Fitness: 109.795, Size: 27
# 	Population - 	Average Fitness: -150.3631868171628
# 	mean = -150.36, 	median = -46.06, 	best_median = -13.78
#
# Generation: 19
# 	Best - 	Fitness: 40.798, Size: 27
# 	Population - 	Average Fitness: -133.50032822465957
# 	mean = -133.50, 	median = -59.96, 	best_median = -13.78
#
# Generation: 20
# 	Best - 	Fitness: 24.183, Size: 27
# 	Population - 	Average Fitness: -159.73460405974063
# 	mean = -159.73, 	median = -109.26, 	best_median = -13.78
#
# Generation: 21
# 	Best - 	Fitness: -16.231, Size: 27
# 	Population - 	Average Fitness: -118.84262763544477
# 	mean = -118.84, 	median = -75.15, 	best_median = -13.78
#
# Generation: 22
# 	Best - 	Fitness: -20.596, Size: 31
# 	Population - 	Average Fitness: -151.54779815293432
# 	mean = -151.55, 	median = -94.45, 	best_median = -13.78
#
# Generation: 23
# 	Best - 	Fitness: 25.311, Size: 31
# 	Population - 	Average Fitness: -77.25781811937733
# 	mean = -77.26, 	median = -33.14, 	best_median = -13.78
#
# Generation: 24
# 	Best - 	Fitness: 69.118, Size: 31
# 	Population - 	Average Fitness: -76.73231589000305
# 	mean = -76.73, 	median = -19.48, 	best_median = -13.78
#
# Generation: 25
# 	Best - 	Fitness: 147.120, Size: 31
# 	Population - 	Average Fitness: -40.53569647401671
# 	mean = -40.54, 	median = 28.34, 	best_median = 28.34
#
# Generation: 26
# 	Best - 	Fitness: 28.925, Size: 31
# 	Population - 	Average Fitness: -109.15659518555833
# 	mean = -109.16, 	median = -36.14, 	best_median = 28.34
#
# Generation: 27
# 	Best - 	Fitness: 88.189, Size: 31
# 	Population - 	Average Fitness: -72.41414150171738
# 	mean = -72.41, 	median = -32.30, 	best_median = 28.34
#
# Generation: 28
# 	Best - 	Fitness: 137.805, Size: 31
# 	Population - 	Average Fitness: -56.1394619745031
# 	mean = -56.14, 	median = -55.10, 	best_median = 28.34
#
# Generation: 29
# 	Best - 	Fitness: 34.958, Size: 31
# 	Population - 	Average Fitness: -73.60977623075765
# 	mean = -73.61, 	median = -8.16, 	best_median = 28.34
#
# Generation: 30
# 	Best - 	Fitness: 59.957, Size: 31
# 	Population - 	Average Fitness: -59.958825332380115
# 	mean = -59.96, 	median = -14.71, 	best_median = 28.34
#
# Generation: 31
# 	Best - 	Fitness: 111.215, Size: 31
# 	Population - 	Average Fitness: -40.27140906783942
# 	mean = -40.27, 	median = 29.13, 	best_median = 29.13
#
# Generation: 32
# 	Best - 	Fitness: 147.444, Size: 31
# 	Population - 	Average Fitness: 0.715021335992472
# 	mean = 0.72, 	median = 70.19, 	best_median = 70.19
#
# Generation: 33
# 	Best - 	Fitness: 50.621, Size: 31
# 	Population - 	Average Fitness: -76.15335375458959
# 	mean = -76.15, 	median = -28.75, 	best_median = 70.19
#
# Generation: 34
# 	Best - 	Fitness: 79.008, Size: 31
# 	Population - 	Average Fitness: -36.50975030328042
# 	mean = -36.51, 	median = 8.30, 	best_median = 70.19
#
# Generation: 35
# 	Best - 	Fitness: 86.937, Size: 31
# 	Population - 	Average Fitness: -47.85362604278278
# 	mean = -47.85, 	median = 6.45, 	best_median = 70.19
#
# Generation: 36
# 	Best - 	Fitness: 130.765, Size: 31
# 	Population - 	Average Fitness: 3.3424511843101334
# 	mean = 3.34, 	median = 69.75, 	best_median = 70.19
#
# Generation: 37
# 	Best - 	Fitness: 76.988, Size: 31
# 	Population - 	Average Fitness: -70.29188081731013
# 	mean = -70.29, 	median = -22.56, 	best_median = 70.19
#
# Generation: 38
# 	Best - 	Fitness: 56.453, Size: 31
# 	Population - 	Average Fitness: -42.97013996477776
# 	mean = -42.97, 	median = 3.70, 	best_median = 70.19
#
# Generation: 39
# 	Best - 	Fitness: 26.691, Size: 31
# 	Population - 	Average Fitness: -95.27597987080159
# 	mean = -95.28, 	median = -38.43, 	best_median = 70.19
#
# Generation: 40
# 	Best - 	Fitness: 149.750, Size: 31
# 	Population - 	Average Fitness: -61.830363390521704
# 	mean = -61.83, 	median = 16.06, 	best_median = 70.19
#
# Generation: 41
# 	Best - 	Fitness: 170.924, Size: 31
# 	Population - 	Average Fitness: 23.80814646881457
# 	mean = 23.81, 	median = 112.31, 	best_median = 112.31
#
# Generation: 42
# 	Best - 	Fitness: 124.487, Size: 31
# 	Population - 	Average Fitness: 20.434451327877436
# 	mean = 20.43, 	median = 83.68, 	best_median = 112.31
#
# Generation: 43
# 	Best - 	Fitness: 99.879, Size: 31
# 	Population - 	Average Fitness: -11.276958887552656
# 	mean = -11.28, 	median = 49.89, 	best_median = 112.31
#
# Generation: 44
# 	Best - 	Fitness: 139.552, Size: 31
# 	Population - 	Average Fitness: -5.465288737397409
# 	mean = -5.47, 	median = 71.42, 	best_median = 112.31
#
# Generation: 45
# 	Best - 	Fitness: 104.611, Size: 31
# 	Population - 	Average Fitness: -28.13120428362604
# 	mean = -28.13, 	median = 70.68, 	best_median = 112.31
#
# Generation: 46
# 	Best - 	Fitness: 133.584, Size: 31
# 	Population - 	Average Fitness: 3.2553036976918728
# 	mean = 3.26, 	median = 64.17, 	best_median = 112.31
#
# Generation: 47
# 	Best - 	Fitness: 45.899, Size: 31
# 	Population - 	Average Fitness: -42.4597551599906
# 	mean = -42.46, 	median = 15.78, 	best_median = 112.31
#
# Generation: 48
# 	Best - 	Fitness: 33.831, Size: 31
# 	Population - 	Average Fitness: -58.3403805885195
# 	mean = -58.34, 	median = -7.78, 	best_median = 112.31
#
# Generation: 49
# 	Best - 	Fitness: 147.151, Size: 31
# 	Population - 	Average Fitness: -32.21798136036752
# 	mean = -32.22, 	median = 82.07, 	best_median = 112.31
#
# Generation: 50
# 	Best - 	Fitness: 157.353, Size: 31
# 	Population - 	Average Fitness: 17.00648904929991
# 	mean = 17.01, 	median = 85.88, 	best_median = 112.31
#
# ------ Evolution 2 ------
# Generation: 1
# 	Best - 	Fitness: -32.671, Size: 19
# 	Population - 	Average Fitness: -220.0654476927605
# 	mean = -220.07, 	median = -132.83, 	best_median = -132.83
#
# Generation: 2
# 	Best - 	Fitness: -62.696, Size: 22
# 	Population - 	Average Fitness: -220.92406102679632
# 	mean = -220.92, 	median = -129.45, 	best_median = -129.45
#
# Generation: 3
# 	Best - 	Fitness: -15.356, Size: 22
# 	Population - 	Average Fitness: -182.93836816097775
# 	mean = -182.94, 	median = -135.84, 	best_median = -129.45
#
# Generation: 4
# 	Best - 	Fitness: -27.235, Size: 22
# 	Population - 	Average Fitness: -202.21827479559045
# 	mean = -202.22, 	median = -149.56, 	best_median = -129.45
#
# Generation: 5
# 	Best - 	Fitness: -29.187, Size: 29
# 	Population - 	Average Fitness: -117.75927513298876
# 	mean = -117.76, 	median = -99.41, 	best_median = -99.41
#
# Generation: 6
# 	Best - 	Fitness: -10.478, Size: 20
# 	Population - 	Average Fitness: -145.93378006799992
# 	mean = -145.93, 	median = -75.70, 	best_median = -75.70
#
# Generation: 7
# 	Best - 	Fitness: 0.290, Size: 28
# 	Population - 	Average Fitness: -115.37698478049406
# 	mean = -115.38, 	median = -42.62, 	best_median = -42.62
#
# Generation: 8
# 	Best - 	Fitness: 1.661, Size: 20
# 	Population - 	Average Fitness: -135.83752770192976
# 	mean = -135.84, 	median = -47.51, 	best_median = -42.62
#
# Generation: 9
# 	Best - 	Fitness: 97.577, Size: 20
# 	Population - 	Average Fitness: -107.40210253184449
# 	mean = -107.40, 	median = -29.62, 	best_median = -29.62
#
# Generation: 10
# 	Best - 	Fitness: 0.455, Size: 20
# 	Population - 	Average Fitness: -148.66193735390644
# 	mean = -148.66, 	median = -56.38, 	best_median = -29.62
#
# Generation: 11
# 	Best - 	Fitness: 27.933, Size: 18
# 	Population - 	Average Fitness: -118.38998651282841
# 	mean = -118.39, 	median = -41.76, 	best_median = -29.62
#
# Generation: 12
# 	Best - 	Fitness: 92.444, Size: 20
# 	Population - 	Average Fitness: -108.01757035465671
# 	mean = -108.02, 	median = -23.57, 	best_median = -23.57
#
# Generation: 13
# 	Best - 	Fitness: 84.116, Size: 28
# 	Population - 	Average Fitness: -133.36661757126745
# 	mean = -133.37, 	median = -28.22, 	best_median = -23.57
#
# Generation: 14
# 	Best - 	Fitness: 33.831, Size: 28
# 	Population - 	Average Fitness: -97.76925600345746
# 	mean = -97.77, 	median = -32.36, 	best_median = -23.57
#
# Generation: 15
# 	Best - 	Fitness: 11.462, Size: 28
# 	Population - 	Average Fitness: -113.81709906007438
# 	mean = -113.82, 	median = -32.14, 	best_median = -23.57
#
# Generation: 16
# 	Best - 	Fitness: 46.397, Size: 28
# 	Population - 	Average Fitness: -58.15413237102289
# 	mean = -58.15, 	median = 25.04, 	best_median = 25.04
#
# Generation: 17
# 	Best - 	Fitness: 109.471, Size: 30
# 	Population - 	Average Fitness: -64.30919767411271
# 	mean = -64.31, 	median = 21.91, 	best_median = 25.04
#
# Generation: 18
# 	Best - 	Fitness: 180.239, Size: 28
# 	Population - 	Average Fitness: -71.83628985618404
# 	mean = -71.84, 	median = 37.98, 	best_median = 37.98
#
# Generation: 19
# 	Best - 	Fitness: 49.173, Size: 28
# 	Population - 	Average Fitness: -93.54191520124458
# 	mean = -93.54, 	median = -49.24, 	best_median = 37.98
#
# Generation: 20
# 	Best - 	Fitness: 98.208, Size: 21
# 	Population - 	Average Fitness: -73.74487424241376
# 	mean = -73.74, 	median = -18.77, 	best_median = 37.98
#
# Generation: 21
# 	Best - 	Fitness: 52.432, Size: 30
# 	Population - 	Average Fitness: -68.7664066222527
# 	mean = -68.77, 	median = 30.31, 	best_median = 37.98
#
# Generation: 22
# 	Best - 	Fitness: 2.599, Size: 28
# 	Population - 	Average Fitness: -141.5850981750167
# 	mean = -141.59, 	median = -53.02, 	best_median = 37.98
#
# Generation: 23
# 	Best - 	Fitness: 82.006, Size: 30
# 	Population - 	Average Fitness: -62.41929296335614
# 	mean = -62.42, 	median = -24.31, 	best_median = 37.98
#
# Generation: 24
# 	Best - 	Fitness: 126.822, Size: 22
# 	Population - 	Average Fitness: -11.20204621425908
# 	mean = -11.20, 	median = 93.81, 	best_median = 93.81
#
# Generation: 25
# 	Best - 	Fitness: 157.582, Size: 30
# 	Population - 	Average Fitness: -42.65157163864458
# 	mean = -42.65, 	median = 53.24, 	best_median = 93.81
#
# Generation: 26
# 	Best - 	Fitness: 151.201, Size: 30
# 	Population - 	Average Fitness: -31.619164593106355
# 	mean = -31.62, 	median = 61.86, 	best_median = 93.81
#
# Generation: 27
# 	Best - 	Fitness: 104.936, Size: 30
# 	Population - 	Average Fitness: -78.00353417727614
# 	mean = -78.00, 	median = -37.13, 	best_median = 93.81
#
# Generation: 28
# 	Best - 	Fitness: 114.056, Size: 30
# 	Population - 	Average Fitness: -69.58124667119378
# 	mean = -69.58, 	median = 35.89, 	best_median = 93.81
#
# Generation: 29
# 	Best - 	Fitness: -49.709, Size: 30
# 	Population - 	Average Fitness: -139.28593153173944
# 	mean = -139.29, 	median = -82.68, 	best_median = 93.81
#
# Generation: 30
# 	Best - 	Fitness: 30.759, Size: 27
# 	Population - 	Average Fitness: -75.18467554408079
# 	mean = -75.18, 	median = -22.29, 	best_median = 93.81
#
# Generation: 31
# 	Best - 	Fitness: 80.514, Size: 30
# 	Population - 	Average Fitness: -45.60842087240483
# 	mean = -45.61, 	median = 46.93, 	best_median = 93.81
#
# Generation: 32
# 	Best - 	Fitness: 159.505, Size: 27
# 	Population - 	Average Fitness: -14.484080886042678
# 	mean = -14.48, 	median = 66.05, 	best_median = 93.81
#
# Generation: 33
# 	Best - 	Fitness: 14.310, Size: 27
# 	Population - 	Average Fitness: -69.91696612506426
# 	mean = -69.92, 	median = -1.62, 	best_median = 93.81
#
# Generation: 34
# 	Best - 	Fitness: -21.529, Size: 27
# 	Population - 	Average Fitness: -101.90130570164689
# 	mean = -101.90, 	median = -21.98, 	best_median = 93.81
#
# Generation: 35
# 	Best - 	Fitness: -37.749, Size: 27
# 	Population - 	Average Fitness: -101.0485587688329
# 	mean = -101.05, 	median = -40.91, 	best_median = 93.81
#
# Generation: 36
# 	Best - 	Fitness: 204.184, Size: 30
# 	Population - 	Average Fitness: 7.361486130801773
# 	mean = 7.36, 	median = 101.59, 	best_median = 101.59
#
# Generation: 37
# 	Best - 	Fitness: 5.944, Size: 27
# 	Population - 	Average Fitness: -123.7522629287133
# 	mean = -123.75, 	median = -78.33, 	best_median = 101.59
#
# Generation: 38
# 	Best - 	Fitness: 31.024, Size: 27
# 	Population - 	Average Fitness: -71.18984147881608
# 	mean = -71.19, 	median = -19.65, 	best_median = 101.59
#
# Generation: 39
# 	Best - 	Fitness: -50.946, Size: 30
# 	Population - 	Average Fitness: -140.28055181582556
# 	mean = -140.28, 	median = -69.31, 	best_median = 101.59
#
# Generation: 40
# 	Best - 	Fitness: 140.637, Size: 29
# 	Population - 	Average Fitness: -49.80615531029777
# 	mean = -49.81, 	median = -31.08, 	best_median = 101.59
#
# Generation: 41
# 	Best - 	Fitness: 93.416, Size: 27
# 	Population - 	Average Fitness: -84.38450191129078
# 	mean = -84.38, 	median = 45.27, 	best_median = 101.59
#
# Generation: 42
# 	Best - 	Fitness: 103.688, Size: 27
# 	Population - 	Average Fitness: -68.20408821802631
# 	mean = -68.20, 	median = 8.32, 	best_median = 101.59
#
# Generation: 43
# 	Best - 	Fitness: 91.802, Size: 27
# 	Population - 	Average Fitness: -43.89751392087578
# 	mean = -43.90, 	median = -6.10, 	best_median = 101.59
#
# Generation: 44
# 	Best - 	Fitness: 78.757, Size: 30
# 	Population - 	Average Fitness: -35.93872543866476
# 	mean = -35.94, 	median = 71.67, 	best_median = 101.59
#
# Generation: 45
# 	Best - 	Fitness: 25.517, Size: 27
# 	Population - 	Average Fitness: -92.50183737701019
# 	mean = -92.50, 	median = -25.99, 	best_median = 101.59
#
# Generation: 46
# 	Best - 	Fitness: 115.049, Size: 25
# 	Population - 	Average Fitness: -77.36190870641096
# 	mean = -77.36, 	median = -15.95, 	best_median = 101.59
#
# Generation: 47
# 	Best - 	Fitness: 37.609, Size: 29
# 	Population - 	Average Fitness: -68.94675041206617
# 	mean = -68.95, 	median = 33.11, 	best_median = 101.59
#
# Generation: 48
# 	Best - 	Fitness: 35.606, Size: 29
# 	Population - 	Average Fitness: -60.161250422059865
# 	mean = -60.16, 	median = 23.17, 	best_median = 101.59
#
# Generation: 49
# 	Best - 	Fitness: -7.901, Size: 29
# 	Population - 	Average Fitness: -102.9651502733805
# 	mean = -102.97, 	median = -36.73, 	best_median = 101.59
#
# Generation: 50
# 	Best - 	Fitness: 124.549, Size: 31
# 	Population - 	Average Fitness: -62.72681416662054
# 	mean = -62.73, 	median = -18.39, 	best_median = 101.59
#
# ------ Evolution 3 ------
# Generation: 1
# 	Best - 	Fitness: -42.376, Size: 12
# 	Population - 	Average Fitness: -233.64014902382326
# 	mean = -233.64, 	median = -129.02, 	best_median = -129.02
#
# Generation: 2
# 	Best - 	Fitness: -45.494, Size: 15
# 	Population - 	Average Fitness: -232.630001902093
# 	mean = -232.63, 	median = -139.68, 	best_median = -129.02
#
# Generation: 3
# 	Best - 	Fitness: -22.854, Size: 19
# 	Population - 	Average Fitness: -167.42002725273406
# 	mean = -167.42, 	median = -117.11, 	best_median = -117.11
#
# Generation: 4
# 	Best - 	Fitness: -39.964, Size: 15
# 	Population - 	Average Fitness: -168.3751090806507
# 	mean = -168.38, 	median = -111.31, 	best_median = -111.31
#
# Generation: 5
# 	Best - 	Fitness: -13.110, Size: 23
# 	Population - 	Average Fitness: -91.77733393594087
# 	mean = -91.78, 	median = -35.55, 	best_median = -35.55
#
# Generation: 6
# 	Best - 	Fitness: -20.142, Size: 29
# 	Population - 	Average Fitness: -82.02054314219
# 	mean = -82.02, 	median = -29.54, 	best_median = -29.54
#
# Generation: 7
# 	Best - 	Fitness: -33.243, Size: 29
# 	Population - 	Average Fitness: -88.72247230570296
# 	mean = -88.72, 	median = -38.40, 	best_median = -29.54
#
# Generation: 8
# 	Best - 	Fitness: -37.601, Size: 18
# 	Population - 	Average Fitness: -98.1982111858842
# 	mean = -98.20, 	median = -43.25, 	best_median = -29.54
#
# Generation: 9
# 	Best - 	Fitness: -25.487, Size: 22
# 	Population - 	Average Fitness: -74.63555182495266
# 	mean = -74.64, 	median = -36.58, 	best_median = -29.54
#
# Generation: 10
# 	Best - 	Fitness: -31.691, Size: 29
# 	Population - 	Average Fitness: -99.93737051314501
# 	mean = -99.94, 	median = -43.51, 	best_median = -29.54
#
# Generation: 11
# 	Best - 	Fitness: -14.075, Size: 24
# 	Population - 	Average Fitness: -122.00047371319091
# 	mean = -122.00, 	median = -38.55, 	best_median = -29.54
#
# Generation: 12
# 	Best - 	Fitness: 36.674, Size: 24
# 	Population - 	Average Fitness: -98.96073673903854
# 	mean = -98.96, 	median = -27.02, 	best_median = -27.02
#
# Generation: 13
# 	Best - 	Fitness: 11.130, Size: 24
# 	Population - 	Average Fitness: -119.58196695703943
# 	mean = -119.58, 	median = -32.24, 	best_median = -27.02
#
# Generation: 14
# 	Best - 	Fitness: 19.723, Size: 30
# 	Population - 	Average Fitness: -150.43436359734136
# 	mean = -150.43, 	median = -85.23, 	best_median = -27.02
#
# Generation: 15
# 	Best - 	Fitness: 0.343, Size: 30
# 	Population - 	Average Fitness: -138.3847054577246
# 	mean = -138.38, 	median = -66.38, 	best_median = -27.02
#
# Generation: 16
# 	Best - 	Fitness: 41.951, Size: 24
# 	Population - 	Average Fitness: -110.9102161394056
# 	mean = -110.91, 	median = -16.90, 	best_median = -16.90
#
# Generation: 17
# 	Best - 	Fitness: 2.253, Size: 21
# 	Population - 	Average Fitness: -150.725576331946
# 	mean = -150.73, 	median = -72.02, 	best_median = -16.90
#
# Generation: 18
# 	Best - 	Fitness: 18.929, Size: 29
# 	Population - 	Average Fitness: -143.93062101191842
# 	mean = -143.93, 	median = -68.83, 	best_median = -16.90
#
# Generation: 19
# 	Best - 	Fitness: -18.176, Size: 31
# 	Population - 	Average Fitness: -132.26300998961102
# 	mean = -132.26, 	median = -78.59, 	best_median = -16.90
#
# Generation: 20
# 	Best - 	Fitness: 8.239, Size: 31
# 	Population - 	Average Fitness: -124.23439492667565
# 	mean = -124.23, 	median = -16.97, 	best_median = -16.90
#
# Generation: 21
# 	Best - 	Fitness: -11.741, Size: 30
# 	Population - 	Average Fitness: -105.88027920475774
# 	mean = -105.88, 	median = -45.81, 	best_median = -16.90
#
# Generation: 22
# 	Best - 	Fitness: 0.395, Size: 30
# 	Population - 	Average Fitness: -112.99890182141117
# 	mean = -113.00, 	median = -37.87, 	best_median = -16.90
#
# Generation: 23
# 	Best - 	Fitness: -20.184, Size: 29
# 	Population - 	Average Fitness: -191.62211699524616
# 	mean = -191.62, 	median = -171.27, 	best_median = -16.90
#
# Generation: 24
# 	Best - 	Fitness: -0.672, Size: 30
# 	Population - 	Average Fitness: -124.11032940714327
# 	mean = -124.11, 	median = -85.02, 	best_median = -16.90
#
# Generation: 25
# 	Best - 	Fitness: 46.118, Size: 30
# 	Population - 	Average Fitness: -66.63385140725627
# 	mean = -66.63, 	median = -15.88, 	best_median = -15.88
#
# Generation: 26
# 	Best - 	Fitness: 15.699, Size: 30
# 	Population - 	Average Fitness: -139.03610062463434
# 	mean = -139.04, 	median = -105.21, 	best_median = -15.88
#
# Generation: 27
# 	Best - 	Fitness: 20.651, Size: 31
# 	Population - 	Average Fitness: -87.9334078153757
# 	mean = -87.93, 	median = -47.51, 	best_median = -15.88
#
# Generation: 28
# 	Best - 	Fitness: 71.167, Size: 31
# 	Population - 	Average Fitness: -65.71859816913279
# 	mean = -65.72, 	median = -2.04, 	best_median = -2.04
#
# Generation: 29
# 	Best - 	Fitness: -24.664, Size: 30
# 	Population - 	Average Fitness: -109.57304305043026
# 	mean = -109.57, 	median = -70.44, 	best_median = -2.04
#
# Generation: 30
# 	Best - 	Fitness: 11.415, Size: 28
# 	Population - 	Average Fitness: -106.04451543528825
# 	mean = -106.04, 	median = -38.43, 	best_median = -2.04
#
# Generation: 31
# 	Best - 	Fitness: 46.560, Size: 30
# 	Population - 	Average Fitness: -70.32621793762122
# 	mean = -70.33, 	median = -19.67, 	best_median = -2.04
#
# Generation: 32
# 	Best - 	Fitness: 58.194, Size: 28
# 	Population - 	Average Fitness: -87.07037210731491
# 	mean = -87.07, 	median = -15.84, 	best_median = -2.04
#
# Generation: 33
# 	Best - 	Fitness: 23.825, Size: 30
# 	Population - 	Average Fitness: -80.58033766383053
# 	mean = -80.58, 	median = -23.96, 	best_median = -2.04
#
# Generation: 34
# 	Best - 	Fitness: 53.675, Size: 29
# 	Population - 	Average Fitness: -62.549259995321584
# 	mean = -62.55, 	median = 21.12, 	best_median = 21.12
#
# Generation: 35
# 	Best - 	Fitness: 7.899, Size: 30
# 	Population - 	Average Fitness: -91.92257189877625
# 	mean = -91.92, 	median = -14.93, 	best_median = 21.12
#
# Generation: 36
# 	Best - 	Fitness: 41.256, Size: 30
# 	Population - 	Average Fitness: -116.41812318534774
# 	mean = -116.42, 	median = -91.87, 	best_median = 21.12
#
# Generation: 37
# 	Best - 	Fitness: 5.705, Size: 31
# 	Population - 	Average Fitness: -88.78165742170465
# 	mean = -88.78, 	median = -46.94, 	best_median = 21.12
#
# Generation: 38
# 	Best - 	Fitness: 21.137, Size: 23
# 	Population - 	Average Fitness: -106.035025501123
# 	mean = -106.04, 	median = -30.32, 	best_median = 21.12
#
# Generation: 39
# 	Best - 	Fitness: -12.258, Size: 26
# 	Population - 	Average Fitness: -107.78755345470802
# 	mean = -107.79, 	median = -46.90, 	best_median = 21.12
#
# Generation: 40
# 	Best - 	Fitness: 33.029, Size: 31
# 	Population - 	Average Fitness: -96.70345889798985
# 	mean = -96.70, 	median = -26.73, 	best_median = 21.12
#
# Generation: 41
# 	Best - 	Fitness: 19.961, Size: 26
# 	Population - 	Average Fitness: -141.83811453538357
# 	mean = -141.84, 	median = -85.82, 	best_median = 21.12
#
# Generation: 42
# 	Best - 	Fitness: 49.202, Size: 30
# 	Population - 	Average Fitness: -58.82638716748602
# 	mean = -58.83, 	median = 9.49, 	best_median = 21.12
#
# Generation: 43
# 	Best - 	Fitness: 37.187, Size: 26
# 	Population - 	Average Fitness: -89.60850526445319
# 	mean = -89.61, 	median = -14.43, 	best_median = 21.12
#
# Generation: 44
# 	Best - 	Fitness: 30.279, Size: 17
# 	Population - 	Average Fitness: -67.85205280255579
# 	mean = -67.85, 	median = -5.10, 	best_median = 21.12
#
# Generation: 45
# 	Best - 	Fitness: 49.197, Size: 27
# 	Population - 	Average Fitness: -77.11207553478897
# 	mean = -77.11, 	median = -11.07, 	best_median = 21.12
#
# Generation: 46
# 	Best - 	Fitness: 44.282, Size: 31
# 	Population - 	Average Fitness: -124.8051975015623
# 	mean = -124.81, 	median = -111.84, 	best_median = 21.12
#
# Generation: 47
# 	Best - 	Fitness: 20.548, Size: 27
# 	Population - 	Average Fitness: -102.16157811859748
# 	mean = -102.16, 	median = -38.38, 	best_median = 21.12
#
# Generation: 48
# 	Best - 	Fitness: 14.360, Size: 26
# 	Population - 	Average Fitness: -64.74612519515017
# 	mean = -64.75, 	median = -15.03, 	best_median = 21.12
#
# Generation: 49
# 	Best - 	Fitness: 41.660, Size: 28
# 	Population - 	Average Fitness: -105.34790902642135
# 	mean = -105.35, 	median = -50.10, 	best_median = 21.12
#
# Generation: 50
# 	Best - 	Fitness: 56.147, Size: 26
# 	Population - 	Average Fitness: -79.80729601465443
# 	mean = -79.81, 	median = -1.74, 	best_median = 21.12
#
# ------ Evolution 4 ------
# Generation: 1
# 	Best - 	Fitness: -28.940, Size: 20
# 	Population - 	Average Fitness: -193.58099746849751
# 	mean = -193.58, 	median = -129.02, 	best_median = -129.02
#
# Generation: 2
# 	Best - 	Fitness: -44.549, Size: 22
# 	Population - 	Average Fitness: -234.5708502476498
# 	mean = -234.57, 	median = -164.35, 	best_median = -129.02
#
# Generation: 3
# 	Best - 	Fitness: 7.024, Size: 15
# 	Population - 	Average Fitness: -124.11157619797642
# 	mean = -124.11, 	median = -110.12, 	best_median = -110.12
#
# Generation: 4
# 	Best - 	Fitness: -29.908, Size: 22
# 	Population - 	Average Fitness: -116.96110510818376
# 	mean = -116.96, 	median = -71.28, 	best_median = -71.28
#
# Generation: 5
# 	Best - 	Fitness: -28.269, Size: 27
# 	Population - 	Average Fitness: -126.40812363984946
# 	mean = -126.41, 	median = -76.76, 	best_median = -71.28
#
# Generation: 6
# 	Best - 	Fitness: 16.275, Size: 16
# 	Population - 	Average Fitness: -118.8228539824928
# 	mean = -118.82, 	median = -19.71, 	best_median = -19.71
#
# Generation: 7
# 	Best - 	Fitness: -10.328, Size: 31
# 	Population - 	Average Fitness: -124.60143973565079
# 	mean = -124.60, 	median = -40.18, 	best_median = -19.71
#
# Generation: 8
# 	Best - 	Fitness: -31.064, Size: 22
# 	Population - 	Average Fitness: -119.65277649690054
# 	mean = -119.65, 	median = -58.76, 	best_median = -19.71
#
# Generation: 9
# 	Best - 	Fitness: 7.247, Size: 12
# 	Population - 	Average Fitness: -80.09383311204459
# 	mean = -80.09, 	median = -13.30, 	best_median = -13.30
#
# Generation: 10
# 	Best - 	Fitness: -17.744, Size: 23
# 	Population - 	Average Fitness: -121.79263209457572
# 	mean = -121.79, 	median = -55.23, 	best_median = -13.30
#
# Generation: 11
# 	Best - 	Fitness: -19.822, Size: 26
# 	Population - 	Average Fitness: -121.73648369854655
# 	mean = -121.74, 	median = -46.31, 	best_median = -13.30
#
# Generation: 12
# 	Best - 	Fitness: 6.560, Size: 18
# 	Population - 	Average Fitness: -115.54727713218887
# 	mean = -115.55, 	median = -20.69, 	best_median = -13.30
#
# Generation: 13
# 	Best - 	Fitness: -12.464, Size: 26
# 	Population - 	Average Fitness: -146.00441667078877
# 	mean = -146.00, 	median = -30.29, 	best_median = -13.30
#
# Generation: 14
# 	Best - 	Fitness: -10.301, Size: 30
# 	Population - 	Average Fitness: -116.76239357143102
# 	mean = -116.76, 	median = -35.18, 	best_median = -13.30
#
# Generation: 15
# 	Best - 	Fitness: -1.040, Size: 23
# 	Population - 	Average Fitness: -159.17426211752115
# 	mean = -159.17, 	median = -24.11, 	best_median = -13.30
#
# Generation: 16
# 	Best - 	Fitness: 24.895, Size: 13
# 	Population - 	Average Fitness: -104.31507850700154
# 	mean = -104.32, 	median = -12.05, 	best_median = -12.05
#
# Generation: 17
# 	Best - 	Fitness: 11.921, Size: 30
# 	Population - 	Average Fitness: -138.27397294630836
# 	mean = -138.27, 	median = -46.34, 	best_median = -12.05
#
# Generation: 18
# 	Best - 	Fitness: 16.133, Size: 28
# 	Population - 	Average Fitness: -130.80717701539027
# 	mean = -130.81, 	median = -15.61, 	best_median = -12.05
#
# Generation: 19
# 	Best - 	Fitness: -18.471, Size: 29
# 	Population - 	Average Fitness: -118.23107507402682
# 	mean = -118.23, 	median = -39.47, 	best_median = -12.05
#
# Generation: 20
# 	Best - 	Fitness: 51.985, Size: 20
# 	Population - 	Average Fitness: -105.13853713054861
# 	mean = -105.14, 	median = 21.68, 	best_median = 21.68
#
# Generation: 21
# 	Best - 	Fitness: -5.259, Size: 28
# 	Population - 	Average Fitness: -169.89220342297472
# 	mean = -169.89, 	median = -52.73, 	best_median = 21.68
#
# Generation: 22
# 	Best - 	Fitness: -6.455, Size: 15
# 	Population - 	Average Fitness: -133.9691531756546
# 	mean = -133.97, 	median = -39.74, 	best_median = 21.68
#
# Generation: 23
# 	Best - 	Fitness: 49.510, Size: 28
# 	Population - 	Average Fitness: -145.88533834994436
# 	mean = -145.89, 	median = -38.15, 	best_median = 21.68
#
# Generation: 24
# 	Best - 	Fitness: 28.027, Size: 28
# 	Population - 	Average Fitness: -125.91541949710793
# 	mean = -125.92, 	median = -18.26, 	best_median = 21.68
#
# Generation: 25
# 	Best - 	Fitness: 191.256, Size: 28
# 	Population - 	Average Fitness: -24.947406178949734
# 	mean = -24.95, 	median = 87.09, 	best_median = 87.09
#
# Generation: 26
# 	Best - 	Fitness: 83.273, Size: 31
# 	Population - 	Average Fitness: -79.43128776340592
# 	mean = -79.43, 	median = 12.54, 	best_median = 87.09
#
# Generation: 27
# 	Best - 	Fitness: 135.635, Size: 28
# 	Population - 	Average Fitness: -74.07695321917811
# 	mean = -74.08, 	median = 58.83, 	best_median = 87.09
#
# Generation: 28
# 	Best - 	Fitness: 72.869, Size: 28
# 	Population - 	Average Fitness: -83.74465214420246
# 	mean = -83.74, 	median = 25.01, 	best_median = 87.09
#
# Generation: 29
# 	Best - 	Fitness: 2.441, Size: 29
# 	Population - 	Average Fitness: -127.7641994150509
# 	mean = -127.76, 	median = -33.35, 	best_median = 87.09
#
# Generation: 30
# 	Best - 	Fitness: 51.181, Size: 31
# 	Population - 	Average Fitness: -108.32030246005657
# 	mean = -108.32, 	median = -28.15, 	best_median = 87.09
#
# Generation: 31
# 	Best - 	Fitness: 95.031, Size: 28
# 	Population - 	Average Fitness: -98.30567076160723
# 	mean = -98.31, 	median = 19.83, 	best_median = 87.09
#
# Generation: 32
# 	Best - 	Fitness: 97.861, Size: 28
# 	Population - 	Average Fitness: -74.32420735556794
# 	mean = -74.32, 	median = 18.13, 	best_median = 87.09
#
# Generation: 33
# 	Best - 	Fitness: 32.581, Size: 26
# 	Population - 	Average Fitness: -86.77236404723241
# 	mean = -86.77, 	median = -10.91, 	best_median = 87.09
#
# Generation: 34
# 	Best - 	Fitness: 91.979, Size: 28
# 	Population - 	Average Fitness: -77.45089342404209
# 	mean = -77.45, 	median = 1.00, 	best_median = 87.09
#
# Generation: 35
# 	Best - 	Fitness: 30.661, Size: 27
# 	Population - 	Average Fitness: -101.23515640673408
# 	mean = -101.24, 	median = -17.12, 	best_median = 87.09
#
# Generation: 36
# 	Best - 	Fitness: 98.511, Size: 24
# 	Population - 	Average Fitness: -53.08640406349475
# 	mean = -53.09, 	median = 27.65, 	best_median = 87.09
#
# Generation: 37
# 	Best - 	Fitness: 49.834, Size: 28
# 	Population - 	Average Fitness: -129.99355710570796
# 	mean = -129.99, 	median = -43.60, 	best_median = 87.09
#
# Generation: 38
# 	Best - 	Fitness: 79.714, Size: 28
# 	Population - 	Average Fitness: -66.78216142666557
# 	mean = -66.78, 	median = 0.46, 	best_median = 87.09
#
# Generation: 39
# 	Best - 	Fitness: 101.340, Size: 30
# 	Population - 	Average Fitness: -42.948322282913374
# 	mean = -42.95, 	median = 51.47, 	best_median = 87.09
#
# Generation: 40
# 	Best - 	Fitness: 94.707, Size: 31
# 	Population - 	Average Fitness: -98.91702062461174
# 	mean = -98.92, 	median = 18.97, 	best_median = 87.09
#
# Generation: 41
# 	Best - 	Fitness: 165.496, Size: 28
# 	Population - 	Average Fitness: -31.81415786207509
# 	mean = -31.81, 	median = 68.53, 	best_median = 87.09
#
# Generation: 42
# 	Best - 	Fitness: 79.948, Size: 28
# 	Population - 	Average Fitness: -92.97458327478593
# 	mean = -92.97, 	median = -29.46, 	best_median = 87.09
#
# Generation: 43
# 	Best - 	Fitness: 70.211, Size: 28
# 	Population - 	Average Fitness: -107.77504319053152
# 	mean = -107.78, 	median = -20.79, 	best_median = 87.09
#
# Generation: 44
# 	Best - 	Fitness: 91.672, Size: 28
# 	Population - 	Average Fitness: -122.29389141654916
# 	mean = -122.29, 	median = -2.84, 	best_median = 87.09
#
# Generation: 45
# 	Best - 	Fitness: 41.076, Size: 29
# 	Population - 	Average Fitness: -107.33916198020171
# 	mean = -107.34, 	median = 11.08, 	best_median = 87.09
#
# Generation: 46
# 	Best - 	Fitness: 148.215, Size: 28
# 	Population - 	Average Fitness: -49.71269198753686
# 	mean = -49.71, 	median = 72.02, 	best_median = 87.09
#
# Generation: 47
# 	Best - 	Fitness: 10.253, Size: 28
# 	Population - 	Average Fitness: -109.60612075000435
# 	mean = -109.61, 	median = -20.97, 	best_median = 87.09
#
# Generation: 48
# 	Best - 	Fitness: 48.041, Size: 30
# 	Population - 	Average Fitness: -66.50527546289867
# 	mean = -66.51, 	median = 40.49, 	best_median = 87.09
#
# Generation: 49
# 	Best - 	Fitness: 93.409, Size: 31
# 	Population - 	Average Fitness: -94.86964038823744
# 	mean = -94.87, 	median = 38.73, 	best_median = 87.09
#
# Generation: 50
# 	Best - 	Fitness: 76.425, Size: 30
# 	Population - 	Average Fitness: -111.98580955806618
# 	mean = -111.99, 	median = -10.76, 	best_median = 87.09

# %% [markdown]
# # Save the Evolution

# %%
import pickle

with open('elite-archive.pickle', 'wb') as file:
    pickle.dump(evo, file, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Test

# %%
def get_test_score(tree):
    rewards = []

    for i in range(10):
      # get initial state
      observation = env.reset(seed=i)
      observation = observation[0]

      for _ in range(500):    
        # build up the input sample for GP
        input_sample = torch.from_numpy(observation.reshape((1,-1))).float()
        # get output (squeezing because it is encapsulated in an array)
        output = tree.get_output_pt(input_sample)
        action = torch.argmax(output)
        observation, reward, terminated, truncated, info = env.step(action.item())
        rewards.append(reward)

        output_sample = torch.from_numpy(observation.reshape((1,-1))).float()
        if (terminated or truncated):
            break

    fitness = np.mean(rewards)
    
    return fitness

best = evo.best_of_gens[-1]

print(best.get_readable_repr())
print(get_test_score(best))
# Out:
# ['sqrt(abs(x_1))', '((sqrt(abs(x_1))+(sqrt(abs(x_1))+max(log(abs(x_7)),((x_3*x_5)+x_6))))+(sin(((sqrt(abs(x_1))+x_0)-sin(x_6)))+max(x_3,x_3)))', '(max(x_7,(x_5)**2)+((log(abs(x_3))+max(sqrt(abs(log(abs(x_2)))),sqrt(abs(x_0))))+sin(cos(x_0))))', '((x_5-(sqrt(abs(x_4))-cos(sqrt(abs(sqrt(abs(x_6)))))))/sin(min(cos((cos(x_6)/sin((x_4-x_4)))),x_5)))']
# 0.29488210233603424

# %% [markdown]
# ## Make an animation
# Here the best evolved individual is selected and one episode is rendered. Make sure to save your lunar landers over time to track progress and make comparisons.

# %%
frames = []

# gist to save gif from https://gist.github.com/botforge/64cbb71780e6208172bbf03cd9293553
def save_frames_as_gif(frames, path='./', filename='evolved_lander.gif'):
  plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi=72)
  patch = plt.imshow(frames[0])
  plt.axis('off')
  def animate(i):
      patch.set_data(frames[i])
  anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
  anim.save(path + filename, writer='imagemagick', fps=60)

frames = []
fitness_function_pt(best, generation = 0, num_episodes=1, episode_duration=500, render=True, ignore_done=False)
env.close()
save_frames_as_gif(frames)

# %% [markdown]
# ## Play animation

# %% [markdown]
# <img src="evolved_lander.gif" width="750">

# %% [markdown]
# ## Optimisation
# The coefficients in the multi-tree aren't optimised. Here Q-learning (taken from https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html) is used to optimise the weights further. Incorporate coefficient optimisation in training your agent(s). Coefficient Optimisation can be expensive. Think about how often you want to optimise, when, which individuals etc.

# %%
batch_size = 128
GAMMA = 0.99

constants = best.get_subtrees_consts()

if len(constants)>0:
  optimizer = optim.AdamW(constants, lr=1e-3, amsgrad=True)

for _ in range(500):

  if len(constants)>0 and len(evo.memory)>batch_size:
    target_tree = copy.deepcopy(best)

    transitions = evo.memory.sample(batch_size)
    batch = Transition(*zip(*transitions))
    
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                        batch.next_state)), dtype=torch.bool)

    non_final_next_states = torch.cat([s for s in batch.next_state
                                               if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = best.get_output_pt(state_batch).gather(1, action_batch)
    next_state_values = torch.zeros(batch_size, dtype=torch.float)
    with torch.no_grad():
      next_state_values[non_final_mask] = target_tree.get_output_pt(non_final_next_states).max(1)[0].float()

    expected_state_action_values = (next_state_values * GAMMA) + reward_batch
    
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))
   
    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_value_(constants, 100)
    optimizer.step()

print(best.get_readable_repr())
print(get_test_score(best))

# %%
frames = []
fitness_function_pt(best, num_episodes=1, episode_duration=500, render=True, ignore_done=False)
env.close()
save_frames_as_gif(frames, filename='evolved_lander_RL.gif')

# %% [markdown]
# <img src="evolved_lander_RL.gif" width="750">
