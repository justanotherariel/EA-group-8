# %% [markdown]
# # Evolving a Lunar Lander with differentiable Genetic Programming

# %% [markdown]
# ## Installation
# To install the required libraries run the command:

# %%
# %%capture --no-display
# %pip install -r requirements.txt

# %% [markdown]
# ## Imports
# Imports from the standard genepro-multi library are done here. Any adjustments (e.g. different operators) should be made in the notebook.

# %%
import gymnasium as gym

from genepro.node_impl import *
from genepro.evo import Evolution
from genepro.node_impl import Constant

import torch
import torch.optim as optim

import random
import os
import copy
from collections import namedtuple, deque

import matplotlib.pyplot as plt
from matplotlib import animation

# %% [markdown]
# ## Reinforcement Learning Setup
# Here we first setup the Gymnasium environment. Please see https://gymnasium.farama.org/environments/box2d/lunar_lander/ for more information on the environment.
#
# Then a memory buffer is made. This is a buffer in which state transitions are stored. When the buffer reaches its maximum capacity old transitions are replaced by new ones.
#
# A frame buffer is initialised used to later store animation frames of the environment.

# %%
env = gym.make("LunarLander-v2", render_mode="rgb_array")

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

    def __iadd__(self, other):
      self.memory += other.memory
      return self 

    def __add__(self, other):
      self.memory = self.memory + other.memory 
      return self

# %%
frames = []

# %% [markdown]
# ## Fitness Function
#
# Here you get to be creative. The default setup evaluates 5 episodes of 300 frames. Think of what action to pick and what fitness function to use. The Multi-tree takes an input of $n \times d$ where $n$ is a batch of size 1.

# %%
def fitness_function_pt(multitree, generation, num_episodes=5, episode_duration=300, render=False, ignore_done=False):
  memory = ReplayMemory(10000)
  rewards = []

  for i in range(num_episodes):
    # get initial state of the environment
    observation = env.reset(seed=(generation*1000 + i))
    observation = observation[0]
    
    for _ in range(episode_duration):
      if render:
        frames.append(env.render())

      input_sample = torch.from_numpy(observation.reshape((1,-1))).float()
      
      action = torch.argmax(multitree.get_output_pt(input_sample))
      observation, reward, terminated, truncated, info = env.step(action.item())
      rewards.append(reward)
      output_sample = torch.from_numpy(observation.reshape((1,-1))).float()
      memory.push(input_sample, torch.tensor([[action.item()]]), output_sample, torch.tensor([reward]))
      if (terminated or truncated) and not ignore_done:
        break

  fitness = np.sum(rewards)/num_episodes
  return fitness, memory

# %% [markdown]
# ## Evolution Setup & Evolve
# Here the leaf and internal nodes are defined. Think about the odds of sampling a constant in this default configurations. Also think about any operators that could be useful and add them here.
#
# Adjust the population size (multiple of 8 if you want to use the standard tournament selection), max generations and max tree size to taste. Be aware that each of these settings can increase the runtime.

# %%
np.random.seed(42)

num_features = env.observation_space.shape[0]
leaf_nodes = [Feature(i) for i in range(num_features)] + [Constant() for _ in range(1)] + [Pi(), E()]
internal_nodes = [Plus(), Minus(), Times(), Div(), Square(), Sqrt(), Log(), Sin(), Cos(), Max(), Min()] #Add your own operators here

# Run a few times to collect Data
for i in range(5):
  print(f"------ Evolution {i} ------")
  
  evo = Evolution(
    fitness_function_pt, internal_nodes, leaf_nodes,
    4,
    pop_size=256,
    max_gens=50,
    max_tree_size=31,
    n_jobs=8,
    log_data=True,
    verbose=True)
  
  evo.evolve()
# Out:
# Generation: 1
# 	Best - 	Fitness: -45.133, Size: 9
# 	Population - 	Average Fitness: -184.51155725426898
# 	mean = -184.51, 	median = -129.02, 	best_median = -129.02
#
# Generation: 2
# 	Best - 	Fitness: -58.375, Size: 18
# 	Population - 	Average Fitness: -261.15525825458974
# 	mean = -261.16, 	median = -146.90, 	best_median = -129.02
#
# Generation: 3
# 	Best - 	Fitness: -26.143, Size: 18
# 	Population - 	Average Fitness: -185.17003188882424
# 	mean = -185.17, 	median = -125.49, 	best_median = -125.49
#
# Generation: 4
# 	Best - 	Fitness: -38.497, Size: 18
# 	Population - 	Average Fitness: -193.47071924135622
# 	mean = -193.47, 	median = -115.54, 	best_median = -115.54
#
# Generation: 5
# 	Best - 	Fitness: -13.121, Size: 18
# 	Population - 	Average Fitness: -126.66837229943364
# 	mean = -126.67, 	median = -79.39, 	best_median = -79.39
#
# Generation: 6
# 	Best - 	Fitness: 6.736, Size: 18
# 	Population - 	Average Fitness: -138.1548533927253
# 	mean = -138.15, 	median = -51.06, 	best_median = -51.06
#
# Generation: 7
# 	Best - 	Fitness: -5.690, Size: 20
# 	Population - 	Average Fitness: -189.82239278113033
# 	mean = -189.82, 	median = -51.71, 	best_median = -51.06
#
# Generation: 8
# 	Best - 	Fitness: -27.178, Size: 21
# 	Population - 	Average Fitness: -140.3574209131039
# 	mean = -140.36, 	median = -56.10, 	best_median = -51.06
#
# Generation: 9
# 	Best - 	Fitness: -1.425, Size: 21
# 	Population - 	Average Fitness: -104.8543267515777
# 	mean = -104.85, 	median = -22.62, 	best_median = -22.62
#
# Generation: 10
# 	Best - 	Fitness: 15.559, Size: 24
# 	Population - 	Average Fitness: -104.4645402081708
# 	mean = -104.46, 	median = -39.47, 	best_median = -22.62
#
# Generation: 11
# 	Best - 	Fitness: -14.153, Size: 28
# 	Population - 	Average Fitness: -116.46557781129479
# 	mean = -116.47, 	median = -41.46, 	best_median = -22.62
#
# Generation: 12
# 	Best - 	Fitness: 21.802, Size: 24
# 	Population - 	Average Fitness: -68.37436382872029
# 	mean = -68.37, 	median = -14.35, 	best_median = -14.35
#
# Generation: 13
# 	Best - 	Fitness: 33.857, Size: 26
# 	Population - 	Average Fitness: -96.91214017290456
# 	mean = -96.91, 	median = -11.92, 	best_median = -11.92
#
# Generation: 14
# 	Best - 	Fitness: 20.414, Size: 23
# 	Population - 	Average Fitness: -87.1757328187712
# 	mean = -87.18, 	median = -7.38, 	best_median = -7.38
#
# Generation: 15
# 	Best - 	Fitness: 2.966, Size: 24
# 	Population - 	Average Fitness: -88.72175933085181
# 	mean = -88.72, 	median = -17.24, 	best_median = -7.38
#
# Generation: 16
# 	Best - 	Fitness: 44.894, Size: 24
# 	Population - 	Average Fitness: -69.43552870859887
# 	mean = -69.44, 	median = -9.74, 	best_median = -7.38
#
# Generation: 17
# 	Best - 	Fitness: 64.802, Size: 28
# 	Population - 	Average Fitness: -82.45833487162236
# 	mean = -82.46, 	median = -24.85, 	best_median = -7.38
# /home/ariel/University/master/4th-quarter_2023S/evolutionary-algorithms/project-main/env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Generation: 18
# 	Best - 	Fitness: 75.811, Size: 29
# 	Population - 	Average Fitness: -44.051086017983216
# 	mean = -44.05, 	median = 13.57, 	best_median = 13.57
#
# Generation: 19
# 	Best - 	Fitness: -10.146, Size: 29
# 	Population - 	Average Fitness: -82.94621444165338
# 	mean = -82.95, 	median = -33.19, 	best_median = 13.57
#
# Generation: 20
# 	Best - 	Fitness: 65.786, Size: 29
# 	Population - 	Average Fitness: -35.29067474476348
# 	mean = -35.29, 	median = -1.20, 	best_median = 13.57
#
# Generation: 21
# 	Best - 	Fitness: 15.215, Size: 27
# 	Population - 	Average Fitness: -80.72824339282957
# 	mean = -80.73, 	median = -29.87, 	best_median = 13.57
#
# Generation: 22
# 	Best - 	Fitness: 12.838, Size: 21
# 	Population - 	Average Fitness: -88.68186351181991
# 	mean = -88.68, 	median = -32.52, 	best_median = 13.57
#
# Generation: 23
# 	Best - 	Fitness: 46.564, Size: 28
# 	Population - 	Average Fitness: -97.81399128770376
# 	mean = -97.81, 	median = -34.14, 	best_median = 13.57
#
# Generation: 24
# 	Best - 	Fitness: 41.610, Size: 31
# 	Population - 	Average Fitness: -75.80260306960467
# 	mean = -75.80, 	median = -14.41, 	best_median = 13.57
#
# Generation: 25
# 	Best - 	Fitness: 82.829, Size: 26
# 	Population - 	Average Fitness: -48.15045954123685
# 	mean = -48.15, 	median = 7.33, 	best_median = 13.57
#
# Generation: 26
# 	Best - 	Fitness: 76.770, Size: 29
# 	Population - 	Average Fitness: -62.0151956572782
# 	mean = -62.02, 	median = 16.52, 	best_median = 16.52
#
# Generation: 27
# 	Best - 	Fitness: 85.233, Size: 28
# 	Population - 	Average Fitness: -52.559005408391585
# 	mean = -52.56, 	median = -0.71, 	best_median = 16.52
#
# Generation: 28
# 	Best - 	Fitness: 40.982, Size: 27
# 	Population - 	Average Fitness: -67.84432490292224
# 	mean = -67.84, 	median = -9.59, 	best_median = 16.52
#
# Generation: 29
# 	Best - 	Fitness: 28.192, Size: 28
# 	Population - 	Average Fitness: -86.60787875948758
# 	mean = -86.61, 	median = -25.21, 	best_median = 16.52
#
# Generation: 30
# 	Best - 	Fitness: 17.898, Size: 29
# 	Population - 	Average Fitness: -89.20892879614897
# 	mean = -89.21, 	median = -28.72, 	best_median = 16.52
#
# Generation: 31
# 	Best - 	Fitness: 98.807, Size: 31
# 	Population - 	Average Fitness: -41.16265840710834
# 	mean = -41.16, 	median = 20.38, 	best_median = 20.38
#
# Generation: 32
# 	Best - 	Fitness: 108.272, Size: 30
# 	Population - 	Average Fitness: -26.144068247971266
# 	mean = -26.14, 	median = 31.92, 	best_median = 31.92
#
# Generation: 33
# 	Best - 	Fitness: 18.033, Size: 31
# 	Population - 	Average Fitness: -62.87447631203144
# 	mean = -62.87, 	median = 0.05, 	best_median = 31.92
#
# Generation: 34
# 	Best - 	Fitness: 59.829, Size: 31
# 	Population - 	Average Fitness: -70.16619465980834
# 	mean = -70.17, 	median = -13.84, 	best_median = 31.92
#
# Generation: 35
# 	Best - 	Fitness: 31.076, Size: 31
# 	Population - 	Average Fitness: -82.8774300642901
# 	mean = -82.88, 	median = -22.64, 	best_median = 31.92
#
# Generation: 36
# 	Best - 	Fitness: 163.352, Size: 31
# 	Population - 	Average Fitness: -16.444712585304796
# 	mean = -16.44, 	median = 81.57, 	best_median = 81.57
#
# Generation: 37
# 	Best - 	Fitness: 17.791, Size: 31
# 	Population - 	Average Fitness: -77.97270146334779
# 	mean = -77.97, 	median = -38.26, 	best_median = 81.57
#
# Generation: 38
# 	Best - 	Fitness: 50.888, Size: 29
# 	Population - 	Average Fitness: -60.65774887542476
# 	mean = -60.66, 	median = -20.80, 	best_median = 81.57
#
# Generation: 39
# 	Best - 	Fitness: 1.517, Size: 27
# 	Population - 	Average Fitness: -64.2540284920276
# 	mean = -64.25, 	median = -40.53, 	best_median = 81.57
#
# Generation: 40
# 	Best - 	Fitness: 83.214, Size: 31
# 	Population - 	Average Fitness: -51.216650572001996
# 	mean = -51.22, 	median = 19.92, 	best_median = 81.57
#
# Generation: 41
# 	Best - 	Fitness: 90.873, Size: 29
# 	Population - 	Average Fitness: -24.427866500188983
# 	mean = -24.43, 	median = 39.62, 	best_median = 81.57
#
# Generation: 42
# 	Best - 	Fitness: 86.504, Size: 29
# 	Population - 	Average Fitness: -23.625372858426644
# 	mean = -23.63, 	median = 38.10, 	best_median = 81.57
#
# Generation: 43
# 	Best - 	Fitness: 33.046, Size: 31
# 	Population - 	Average Fitness: -71.6514532244967
# 	mean = -71.65, 	median = -16.79, 	best_median = 81.57
#
# Generation: 44
# 	Best - 	Fitness: 100.802, Size: 30
# 	Population - 	Average Fitness: -32.40445683282919
# 	mean = -32.40, 	median = 46.85, 	best_median = 81.57
#
# Generation: 45
# 	Best - 	Fitness: 25.260, Size: 27
# 	Population - 	Average Fitness: -66.18827652394921
# 	mean = -66.19, 	median = -9.92, 	best_median = 81.57
#
# Generation: 46
# 	Best - 	Fitness: 69.189, Size: 31
# 	Population - 	Average Fitness: -38.65475430127049
# 	mean = -38.65, 	median = -11.21, 	best_median = 81.57
#
# Generation: 47
# 	Best - 	Fitness: 12.783, Size: 28
# 	Population - 	Average Fitness: -82.76973896149015
# 	mean = -82.77, 	median = -29.44, 	best_median = 81.57
#
# Generation: 48
# 	Best - 	Fitness: 54.978, Size: 30
# 	Population - 	Average Fitness: -51.28516812000028
# 	mean = -51.29, 	median = -2.25, 	best_median = 81.57
#
# Generation: 49
# 	Best - 	Fitness: 126.077, Size: 30
# 	Population - 	Average Fitness: -38.05830025026482
# 	mean = -38.06, 	median = 4.53, 	best_median = 81.57
#
# Generation: 50
# 	Best - 	Fitness: 104.564, Size: 30
# 	Population - 	Average Fitness: -32.95958165222197
# 	mean = -32.96, 	median = 37.27, 	best_median = 81.57
#
# Generation: 1
# 	Best - 	Fitness: -8.542, Size: 20
# 	Population - 	Average Fitness: -208.06067369153507
# 	mean = -208.06, 	median = -129.02, 	best_median = -129.02
#
# Generation: 2
# 	Best - 	Fitness: -40.505, Size: 18
# 	Population - 	Average Fitness: -267.26396729034263
# 	mean = -267.26, 	median = -163.13, 	best_median = -129.02
#
# Generation: 3
# 	Best - 	Fitness: -31.087, Size: 18
# 	Population - 	Average Fitness: -196.33379829044884
# 	mean = -196.33, 	median = -116.80, 	best_median = -116.80
#
# Generation: 4
# 	Best - 	Fitness: -38.978, Size: 18
# 	Population - 	Average Fitness: -181.1482239241782
# 	mean = -181.15, 	median = -111.80, 	best_median = -111.80
#
# Generation: 5
# 	Best - 	Fitness: -5.291, Size: 26
# 	Population - 	Average Fitness: -131.40294448460637
# 	mean = -131.40, 	median = -97.41, 	best_median = -97.41
#
# Generation: 6
# 	Best - 	Fitness: -1.342, Size: 18
# 	Population - 	Average Fitness: -125.10569297945406
# 	mean = -125.11, 	median = -38.05, 	best_median = -38.05
#
# Generation: 7
# 	Best - 	Fitness: -16.760, Size: 26
# 	Population - 	Average Fitness: -137.79784036854323
# 	mean = -137.80, 	median = -32.01, 	best_median = -32.01
#
# Generation: 8
# 	Best - 	Fitness: -15.155, Size: 26
# 	Population - 	Average Fitness: -112.72565111465684
# 	mean = -112.73, 	median = -33.48, 	best_median = -32.01
#
# Generation: 9
# 	Best - 	Fitness: -22.096, Size: 25
# 	Population - 	Average Fitness: -124.20602822961854
# 	mean = -124.21, 	median = -64.71, 	best_median = -32.01
#
# Generation: 10
# 	Best - 	Fitness: 12.024, Size: 26
# 	Population - 	Average Fitness: -103.64344617227749
# 	mean = -103.64, 	median = -27.89, 	best_median = -27.89
#
# Generation: 11
# 	Best - 	Fitness: 43.484, Size: 25
# 	Population - 	Average Fitness: -109.62047106047152
# 	mean = -109.62, 	median = -19.57, 	best_median = -19.57
#
# Generation: 12
# 	Best - 	Fitness: 197.935, Size: 26
# 	Population - 	Average Fitness: -107.07539408497239
# 	mean = -107.08, 	median = -1.69, 	best_median = -1.69
#
# Generation: 13
# 	Best - 	Fitness: 41.603, Size: 29
# 	Population - 	Average Fitness: -70.67862010868409
# 	mean = -70.68, 	median = -11.57, 	best_median = -1.69
#
# Generation: 14
# 	Best - 	Fitness: 36.489, Size: 26
# 	Population - 	Average Fitness: -92.96052342082234
# 	mean = -92.96, 	median = -33.46, 	best_median = -1.69
#
# Generation: 15
# 	Best - 	Fitness: 9.848, Size: 26
# 	Population - 	Average Fitness: -86.1554370559338
# 	mean = -86.16, 	median = -40.39, 	best_median = -1.69
#
# Generation: 16
# 	Best - 	Fitness: 73.996, Size: 30
# 	Population - 	Average Fitness: -33.114279051245205
# 	mean = -33.11, 	median = -2.22, 	best_median = -1.69
#
# Generation: 17
# 	Best - 	Fitness: 47.318, Size: 26
# 	Population - 	Average Fitness: -75.8444862756029
# 	mean = -75.84, 	median = -27.93, 	best_median = -1.69
#
# Generation: 18
# 	Best - 	Fitness: 28.026, Size: 30
# 	Population - 	Average Fitness: -70.88519567942532
# 	mean = -70.89, 	median = -16.25, 	best_median = -1.69
#
# Generation: 19
# 	Best - 	Fitness: 18.006, Size: 27
# 	Population - 	Average Fitness: -72.13543747749908
# 	mean = -72.14, 	median = -20.87, 	best_median = -1.69
#
# Generation: 20
# 	Best - 	Fitness: 18.655, Size: 27
# 	Population - 	Average Fitness: -99.83163109465954
# 	mean = -99.83, 	median = -80.97, 	best_median = -1.69
#
# Generation: 21
# 	Best - 	Fitness: -17.663, Size: 27
# 	Population - 	Average Fitness: -85.79778671897752
# 	mean = -85.80, 	median = -51.93, 	best_median = -1.69
#
# Generation: 22
# 	Best - 	Fitness: -29.726, Size: 28
# 	Population - 	Average Fitness: -71.01034165538975
# 	mean = -71.01, 	median = -39.40, 	best_median = -1.69
#
# Generation: 23
# 	Best - 	Fitness: -1.071, Size: 29
# 	Population - 	Average Fitness: -92.0144290751304
# 	mean = -92.01, 	median = -44.23, 	best_median = -1.69
#
# Generation: 24
# 	Best - 	Fitness: 24.506, Size: 29
# 	Population - 	Average Fitness: -80.9033034387444
# 	mean = -80.90, 	median = -42.71, 	best_median = -1.69
#
# Generation: 25
# 	Best - 	Fitness: 81.630, Size: 30
# 	Population - 	Average Fitness: -30.898427959871388
# 	mean = -30.90, 	median = 2.97, 	best_median = 2.97
#
# Generation: 26
# 	Best - 	Fitness: -45.753, Size: 28
# 	Population - 	Average Fitness: -106.570898776001
# 	mean = -106.57, 	median = -84.73, 	best_median = 2.97
#
# Generation: 27
# 	Best - 	Fitness: -28.277, Size: 29
# 	Population - 	Average Fitness: -80.06293073609261
# 	mean = -80.06, 	median = -41.11, 	best_median = 2.97
#
# Generation: 28
# 	Best - 	Fitness: 46.096, Size: 31
# 	Population - 	Average Fitness: -33.12986257499311
# 	mean = -33.13, 	median = -7.49, 	best_median = 2.97
#
# Generation: 29
# 	Best - 	Fitness: -24.120, Size: 31
# 	Population - 	Average Fitness: -62.41448066952827
# 	mean = -62.41, 	median = -29.61, 	best_median = 2.97
#
# Generation: 30
# 	Best - 	Fitness: 31.981, Size: 31
# 	Population - 	Average Fitness: -47.8698483646538
# 	mean = -47.87, 	median = -15.53, 	best_median = 2.97
#
# Generation: 31
# 	Best - 	Fitness: 61.629, Size: 27
# 	Population - 	Average Fitness: -31.493550090524977
# 	mean = -31.49, 	median = 16.85, 	best_median = 16.85
#
# Generation: 32
# 	Best - 	Fitness: 36.221, Size: 27
# 	Population - 	Average Fitness: -58.72347768144826
# 	mean = -58.72, 	median = -11.99, 	best_median = 16.85
#
# Generation: 33
# 	Best - 	Fitness: 97.280, Size: 26
# 	Population - 	Average Fitness: -52.92467292010466
# 	mean = -52.92, 	median = 1.54, 	best_median = 16.85
#
# Generation: 34
# 	Best - 	Fitness: 94.017, Size: 29
# 	Population - 	Average Fitness: -30.871317590560945
# 	mean = -30.87, 	median = 7.35, 	best_median = 16.85
#
# Generation: 35
# 	Best - 	Fitness: 96.315, Size: 26
# 	Population - 	Average Fitness: -49.355673344908325
# 	mean = -49.36, 	median = 4.27, 	best_median = 16.85
#
# Generation: 36
# 	Best - 	Fitness: 40.871, Size: 31
# 	Population - 	Average Fitness: -60.09527871243635
# 	mean = -60.10, 	median = -23.50, 	best_median = 16.85
#
# Generation: 37
# 	Best - 	Fitness: 98.707, Size: 26
# 	Population - 	Average Fitness: -26.447586963933663
# 	mean = -26.45, 	median = 32.86, 	best_median = 32.86
#
# Generation: 38
# 	Best - 	Fitness: 62.915, Size: 28
# 	Population - 	Average Fitness: -49.03851407678526
# 	mean = -49.04, 	median = -12.70, 	best_median = 32.86
#
# Generation: 39
# 	Best - 	Fitness: 120.705, Size: 28
# 	Population - 	Average Fitness: -9.672204841304165
# 	mean = -9.67, 	median = 43.58, 	best_median = 43.58
#
# Generation: 40
# 	Best - 	Fitness: 41.359, Size: 29
# 	Population - 	Average Fitness: -61.62905965200057
# 	mean = -61.63, 	median = -15.57, 	best_median = 43.58
#
# Generation: 41
# 	Best - 	Fitness: 106.717, Size: 23
# 	Population - 	Average Fitness: -53.80585875770754
# 	mean = -53.81, 	median = -16.07, 	best_median = 43.58
#
# Generation: 42
# 	Best - 	Fitness: 120.114, Size: 31
# 	Population - 	Average Fitness: -9.639764612959558
# 	mean = -9.64, 	median = 36.68, 	best_median = 43.58
#
# Generation: 43
# 	Best - 	Fitness: 33.479, Size: 28
# 	Population - 	Average Fitness: -48.35590075316944
# 	mean = -48.36, 	median = -8.22, 	best_median = 43.58
#
# Generation: 44
# 	Best - 	Fitness: 78.157, Size: 31
# 	Population - 	Average Fitness: 0.8961354386122675
# 	mean = 0.90, 	median = 53.91, 	best_median = 53.91
#
# Generation: 45
# 	Best - 	Fitness: 67.176, Size: 29
# 	Population - 	Average Fitness: -36.11573947711688
# 	mean = -36.12, 	median = 15.03, 	best_median = 53.91
#
# Generation: 46
# 	Best - 	Fitness: 48.347, Size: 31
# 	Population - 	Average Fitness: -66.62999341673603
# 	mean = -66.63, 	median = -30.15, 	best_median = 53.91
#
# Generation: 47
# 	Best - 	Fitness: 71.093, Size: 31
# 	Population - 	Average Fitness: -96.56697335224605
# 	mean = -96.57, 	median = -64.41, 	best_median = 53.91
#
# Generation: 48
# 	Best - 	Fitness: 112.748, Size: 28
# 	Population - 	Average Fitness: -55.07721979359883
# 	mean = -55.08, 	median = -28.69, 	best_median = 53.91
#
# Generation: 49
# 	Best - 	Fitness: 105.114, Size: 30
# 	Population - 	Average Fitness: -13.69255317662705
# 	mean = -13.69, 	median = 33.86, 	best_median = 53.91
#
# Generation: 50
# 	Best - 	Fitness: 95.968, Size: 29
# 	Population - 	Average Fitness: -39.71595504343518
# 	mean = -39.72, 	median = 18.91, 	best_median = 53.91
#
# Generation: 1
# 	Best - 	Fitness: -14.592, Size: 13
# 	Population - 	Average Fitness: -235.26253373738052
# 	mean = -235.26, 	median = -129.02, 	best_median = -129.02
#
# Generation: 2
# 	Best - 	Fitness: -81.138, Size: 11
# 	Population - 	Average Fitness: -234.74239126616595
# 	mean = -234.74, 	median = -129.35, 	best_median = -129.02
#
# Generation: 3
# 	Best - 	Fitness: -78.420, Size: 21
# 	Population - 	Average Fitness: -188.24983325350075
# 	mean = -188.25, 	median = -116.14, 	best_median = -116.14
#
# Generation: 4
# 	Best - 	Fitness: -40.242, Size: 29
# 	Population - 	Average Fitness: -214.0079348333155
# 	mean = -214.01, 	median = -131.51, 	best_median = -116.14
#
# Generation: 5
# 	Best - 	Fitness: -18.081, Size: 16
# 	Population - 	Average Fitness: -145.39831771941692
# 	mean = -145.40, 	median = -93.29, 	best_median = -93.29
#
# Generation: 6
# 	Best - 	Fitness: 60.471, Size: 16
# 	Population - 	Average Fitness: -203.94339507918613
# 	mean = -203.94, 	median = -80.63, 	best_median = -80.63
#
# Generation: 7
# 	Best - 	Fitness: 7.862, Size: 26
# 	Population - 	Average Fitness: -149.8067051341638
# 	mean = -149.81, 	median = -76.66, 	best_median = -76.66
#
# Generation: 8
# 	Best - 	Fitness: -28.955, Size: 26
# 	Population - 	Average Fitness: -160.18968322762555
# 	mean = -160.19, 	median = -68.08, 	best_median = -68.08
#
# Generation: 9
# 	Best - 	Fitness: 18.282, Size: 29
# 	Population - 	Average Fitness: -96.94519826021833
# 	mean = -96.95, 	median = -39.39, 	best_median = -39.39
#
# Generation: 10
# 	Best - 	Fitness: -19.657, Size: 25
# 	Population - 	Average Fitness: -132.0976964468204
# 	mean = -132.10, 	median = -57.16, 	best_median = -39.39
#
# Generation: 11
# 	Best - 	Fitness: 22.886, Size: 29
# 	Population - 	Average Fitness: -114.59799643623703
# 	mean = -114.60, 	median = -37.72, 	best_median = -37.72
#
# Generation: 12
# 	Best - 	Fitness: 46.022, Size: 25
# 	Population - 	Average Fitness: -107.87984186405701
# 	mean = -107.88, 	median = -14.72, 	best_median = -14.72
#
# Generation: 13
# 	Best - 	Fitness: 119.570, Size: 29
# 	Population - 	Average Fitness: -107.19791704708948
# 	mean = -107.20, 	median = -22.44, 	best_median = -14.72
#
# Generation: 14
# 	Best - 	Fitness: 19.049, Size: 25
# 	Population - 	Average Fitness: -101.75946152715174
# 	mean = -101.76, 	median = -28.18, 	best_median = -14.72
#
# Generation: 15
# 	Best - 	Fitness: 6.298, Size: 22
# 	Population - 	Average Fitness: -115.22865942607442
# 	mean = -115.23, 	median = -55.08, 	best_median = -14.72
#
# Generation: 16
# 	Best - 	Fitness: 153.788, Size: 21
# 	Population - 	Average Fitness: -67.00168358772221
# 	mean = -67.00, 	median = -15.35, 	best_median = -14.72
#
# Generation: 17
# 	Best - 	Fitness: 75.500, Size: 30
# 	Population - 	Average Fitness: -102.54622859713892
# 	mean = -102.55, 	median = -35.46, 	best_median = -14.72
#
# Generation: 18
# 	Best - 	Fitness: 93.105, Size: 22
# 	Population - 	Average Fitness: -112.09652500743817
# 	mean = -112.10, 	median = -19.93, 	best_median = -14.72
#
# Generation: 19
# 	Best - 	Fitness: 19.617, Size: 25
# 	Population - 	Average Fitness: -104.29213177201865
# 	mean = -104.29, 	median = -41.30, 	best_median = -14.72
#
# Generation: 20
# 	Best - 	Fitness: 74.535, Size: 30
# 	Population - 	Average Fitness: -118.34715504874303
# 	mean = -118.35, 	median = -55.35, 	best_median = -14.72
#
# Generation: 21
# 	Best - 	Fitness: -11.650, Size: 30
# 	Population - 	Average Fitness: -142.0917175149667
# 	mean = -142.09, 	median = -91.38, 	best_median = -14.72
#
# Generation: 22
# 	Best - 	Fitness: 9.193, Size: 30
# 	Population - 	Average Fitness: -109.8161822272149
# 	mean = -109.82, 	median = -45.48, 	best_median = -14.72
#
# Generation: 23
# 	Best - 	Fitness: 25.408, Size: 30
# 	Population - 	Average Fitness: -84.8859312701548
# 	mean = -84.89, 	median = -35.82, 	best_median = -14.72
#
# Generation: 24
# 	Best - 	Fitness: 58.982, Size: 25
# 	Population - 	Average Fitness: -169.87748540155715
# 	mean = -169.88, 	median = -95.43, 	best_median = -14.72
#
# Generation: 25
# 	Best - 	Fitness: 170.955, Size: 30
# 	Population - 	Average Fitness: -58.30640815646288
# 	mean = -58.31, 	median = 1.67, 	best_median = 1.67
#
# Generation: 26
# 	Best - 	Fitness: 70.019, Size: 30
# 	Population - 	Average Fitness: -112.3789293833883
# 	mean = -112.38, 	median = -20.93, 	best_median = 1.67
#
# Generation: 27
# 	Best - 	Fitness: 35.173, Size: 20
# 	Population - 	Average Fitness: -110.05221530495298
# 	mean = -110.05, 	median = -65.30, 	best_median = 1.67
#
# Generation: 28
# 	Best - 	Fitness: 121.948, Size: 31
# 	Population - 	Average Fitness: -63.54375390417304
# 	mean = -63.54, 	median = 13.00, 	best_median = 13.00
#
# Generation: 29
# 	Best - 	Fitness: -11.029, Size: 30
# 	Population - 	Average Fitness: -106.65809136287474
# 	mean = -106.66, 	median = -28.70, 	best_median = 13.00
#
# Generation: 30
# 	Best - 	Fitness: 3.149, Size: 30
# 	Population - 	Average Fitness: -119.38064766640896
# 	mean = -119.38, 	median = -60.53, 	best_median = 13.00
#
# Generation: 31
# 	Best - 	Fitness: 61.345, Size: 28
# 	Population - 	Average Fitness: -102.15162472123735
# 	mean = -102.15, 	median = -9.48, 	best_median = 13.00
#
# Generation: 32
# 	Best - 	Fitness: 39.505, Size: 30
# 	Population - 	Average Fitness: -107.76399984730983
# 	mean = -107.76, 	median = -7.83, 	best_median = 13.00
#
# Generation: 33
# 	Best - 	Fitness: -12.982, Size: 27
# 	Population - 	Average Fitness: -147.4058828306507
# 	mean = -147.41, 	median = -81.23, 	best_median = 13.00
#
# Generation: 34
# 	Best - 	Fitness: 101.939, Size: 28
# 	Population - 	Average Fitness: -98.48856696319207
# 	mean = -98.49, 	median = -34.01, 	best_median = 13.00
#
# Generation: 35
# 	Best - 	Fitness: 13.090, Size: 28
# 	Population - 	Average Fitness: -108.7244735679978
# 	mean = -108.72, 	median = -61.75, 	best_median = 13.00
#
# Generation: 36
# 	Best - 	Fitness: 120.315, Size: 23
# 	Population - 	Average Fitness: -93.14026332839735
# 	mean = -93.14, 	median = -19.89, 	best_median = 13.00
#
# Generation: 37
# 	Best - 	Fitness: -7.365, Size: 28
# 	Population - 	Average Fitness: -122.75979753814933
# 	mean = -122.76, 	median = -55.20, 	best_median = 13.00
#
# Generation: 38
# 	Best - 	Fitness: 3.165, Size: 26
# 	Population - 	Average Fitness: -114.67033168020528
# 	mean = -114.67, 	median = -61.91, 	best_median = 13.00
#
# Generation: 39
# 	Best - 	Fitness: -44.692, Size: 18
# 	Population - 	Average Fitness: -126.70866575169146
# 	mean = -126.71, 	median = -73.45, 	best_median = 13.00
#
# Generation: 40
# 	Best - 	Fitness: 103.585, Size: 27
# 	Population - 	Average Fitness: -112.55997158833559
# 	mean = -112.56, 	median = -36.44, 	best_median = 13.00
#
# Generation: 41
# 	Best - 	Fitness: 97.980, Size: 20
# 	Population - 	Average Fitness: -104.9805994957255
# 	mean = -104.98, 	median = 0.47, 	best_median = 13.00
#
# Generation: 42
# 	Best - 	Fitness: 86.319, Size: 29
# 	Population - 	Average Fitness: -131.22910187773678
# 	mean = -131.23, 	median = -46.15, 	best_median = 13.00
#
# Generation: 43
# 	Best - 	Fitness: 62.749, Size: 30
# 	Population - 	Average Fitness: -108.83643892101084
# 	mean = -108.84, 	median = -20.92, 	best_median = 13.00
#
# Generation: 44
# 	Best - 	Fitness: 133.626, Size: 28
# 	Population - 	Average Fitness: -96.81212995721722
# 	mean = -96.81, 	median = -31.76, 	best_median = 13.00
#
# Generation: 45
# 	Best - 	Fitness: 59.031, Size: 27
# 	Population - 	Average Fitness: -98.01684850121161
# 	mean = -98.02, 	median = -29.57, 	best_median = 13.00
#
# Generation: 46
# 	Best - 	Fitness: 116.238, Size: 28
# 	Population - 	Average Fitness: -98.18177509473931
# 	mean = -98.18, 	median = -38.45, 	best_median = 13.00
#
# Generation: 47
# 	Best - 	Fitness: 85.954, Size: 26
# 	Population - 	Average Fitness: -127.27086050465984
# 	mean = -127.27, 	median = -50.63, 	best_median = 13.00
#
# Generation: 48
# 	Best - 	Fitness: 99.475, Size: 19
# 	Population - 	Average Fitness: -119.36248964575181
# 	mean = -119.36, 	median = -31.99, 	best_median = 13.00
#
# Generation: 49
# 	Best - 	Fitness: 160.383, Size: 26
# 	Population - 	Average Fitness: -115.09955529525817
# 	mean = -115.10, 	median = -10.05, 	best_median = 13.00
#
# Generation: 50
# 	Best - 	Fitness: 129.208, Size: 26
# 	Population - 	Average Fitness: -145.0622017879657
# 	mean = -145.06, 	median = -17.16, 	best_median = 13.00
#
# Generation: 1
# 	Best - 	Fitness: -11.023, Size: 22
# 	Population - 	Average Fitness: -250.036706924578
# 	mean = -250.04, 	median = -129.08, 	best_median = -129.08
#
# Generation: 2
# 	Best - 	Fitness: -104.223, Size: 17
# 	Population - 	Average Fitness: -250.3461423668944
# 	mean = -250.35, 	median = -161.42, 	best_median = -129.08
#
# Generation: 3
# 	Best - 	Fitness: -80.140, Size: 14
# 	Population - 	Average Fitness: -196.58859018769303
# 	mean = -196.59, 	median = -138.44, 	best_median = -129.08
#
# Generation: 4
# 	Best - 	Fitness: -70.728, Size: 22
# 	Population - 	Average Fitness: -242.4754328382617
# 	mean = -242.48, 	median = -145.07, 	best_median = -129.08
#
# Generation: 5
# 	Best - 	Fitness: -11.726, Size: 15
# 	Population - 	Average Fitness: -173.4475364972456
# 	mean = -173.45, 	median = -105.06, 	best_median = -105.06
#
# Generation: 6
# 	Best - 	Fitness: -0.474, Size: 15
# 	Population - 	Average Fitness: -164.87342617447794
# 	mean = -164.87, 	median = -97.43, 	best_median = -97.43
#
# Generation: 7
# 	Best - 	Fitness: 19.875, Size: 15
# 	Population - 	Average Fitness: -169.59318458463758
# 	mean = -169.59, 	median = -121.96, 	best_median = -97.43
#
# Generation: 8
# 	Best - 	Fitness: -3.609, Size: 15
# 	Population - 	Average Fitness: -162.31089738376545
# 	mean = -162.31, 	median = -95.56, 	best_median = -95.56
#
# Generation: 9
# 	Best - 	Fitness: 69.591, Size: 15
# 	Population - 	Average Fitness: -89.9485018087575
# 	mean = -89.95, 	median = -27.64, 	best_median = -27.64
#
# Generation: 10
# 	Best - 	Fitness: 41.259, Size: 30
# 	Population - 	Average Fitness: -102.82272837510283
# 	mean = -102.82, 	median = -10.26, 	best_median = -10.26
#
# Generation: 11
# 	Best - 	Fitness: 8.764, Size: 30
# 	Population - 	Average Fitness: -126.17156848696932
# 	mean = -126.17, 	median = -16.60, 	best_median = -10.26
#
# Generation: 12
# 	Best - 	Fitness: 39.259, Size: 26
# 	Population - 	Average Fitness: -130.66946969483945
# 	mean = -130.67, 	median = -29.42, 	best_median = -10.26
#
# Generation: 13
# 	Best - 	Fitness: 36.638, Size: 17
# 	Population - 	Average Fitness: -163.77467946642778
# 	mean = -163.77, 	median = -27.46, 	best_median = -10.26
#
# Generation: 14
# 	Best - 	Fitness: -20.864, Size: 15
# 	Population - 	Average Fitness: -129.03536136076596
# 	mean = -129.04, 	median = -37.63, 	best_median = -10.26
#
# Generation: 15
# 	Best - 	Fitness: 17.525, Size: 27
# 	Population - 	Average Fitness: -151.9231311151133
# 	mean = -151.92, 	median = -35.41, 	best_median = -10.26
#
# Generation: 16
# 	Best - 	Fitness: 102.205, Size: 26
# 	Population - 	Average Fitness: -40.062902793784545
# 	mean = -40.06, 	median = 51.37, 	best_median = 51.37
#
# Generation: 17
# 	Best - 	Fitness: -14.348, Size: 26
# 	Population - 	Average Fitness: -108.80647613105786
# 	mean = -108.81, 	median = -35.79, 	best_median = 51.37
#
# Generation: 18
# 	Best - 	Fitness: 88.284, Size: 26
# 	Population - 	Average Fitness: -131.86903805739675
# 	mean = -131.87, 	median = 3.35, 	best_median = 51.37
#
# Generation: 19
# 	Best - 	Fitness: -48.232, Size: 30
# 	Population - 	Average Fitness: -138.7212541491088
# 	mean = -138.72, 	median = -64.75, 	best_median = 51.37
#
# Generation: 20
# 	Best - 	Fitness: 11.909, Size: 25
# 	Population - 	Average Fitness: -235.6082094014647
# 	mean = -235.61, 	median = -266.16, 	best_median = 51.37
#
# Generation: 21
# 	Best - 	Fitness: -16.047, Size: 30
# 	Population - 	Average Fitness: -165.2075184631141
# 	mean = -165.21, 	median = -107.52, 	best_median = 51.37
#
# Generation: 22
# 	Best - 	Fitness: 45.089, Size: 30
# 	Population - 	Average Fitness: -136.8217489088942
# 	mean = -136.82, 	median = -33.33, 	best_median = 51.37
#
# Generation: 23
# 	Best - 	Fitness: 45.044, Size: 30
# 	Population - 	Average Fitness: -106.83028010614439
# 	mean = -106.83, 	median = -33.19, 	best_median = 51.37
#
# Generation: 24
# 	Best - 	Fitness: -1.348, Size: 19
# 	Population - 	Average Fitness: -145.82008914466553
# 	mean = -145.82, 	median = -45.53, 	best_median = 51.37
#
# Generation: 25
# 	Best - 	Fitness: 47.874, Size: 30
# 	Population - 	Average Fitness: -45.73219772791825
# 	mean = -45.73, 	median = 25.04, 	best_median = 51.37
#
# Generation: 26
# 	Best - 	Fitness: -12.542, Size: 23
# 	Population - 	Average Fitness: -121.26391496791133
# 	mean = -121.26, 	median = -66.07, 	best_median = 51.37
#
# Generation: 27
# 	Best - 	Fitness: 47.439, Size: 30
# 	Population - 	Average Fitness: -86.69679535081725
# 	mean = -86.70, 	median = -33.85, 	best_median = 51.37
#
# Generation: 28
# 	Best - 	Fitness: 54.298, Size: 28
# 	Population - 	Average Fitness: -92.86705703266132
# 	mean = -92.87, 	median = -27.60, 	best_median = 51.37
#
# Generation: 29
# 	Best - 	Fitness: -36.486, Size: 22
# 	Population - 	Average Fitness: -166.11727762495835
# 	mean = -166.12, 	median = -108.39, 	best_median = 51.37
#
# Generation: 30
# 	Best - 	Fitness: -31.880, Size: 30
# 	Population - 	Average Fitness: -128.47294496161112
# 	mean = -128.47, 	median = -75.12, 	best_median = 51.37
#
# Generation: 31
# 	Best - 	Fitness: -6.998, Size: 30
# 	Population - 	Average Fitness: -117.46246128006437
# 	mean = -117.46, 	median = -48.82, 	best_median = 51.37
#
# Generation: 32
# 	Best - 	Fitness: 58.807, Size: 30
# 	Population - 	Average Fitness: -108.75859040289923
# 	mean = -108.76, 	median = -18.74, 	best_median = 51.37
#
# Generation: 33
# 	Best - 	Fitness: 9.248, Size: 30
# 	Population - 	Average Fitness: -109.97618415435855
# 	mean = -109.98, 	median = -39.18, 	best_median = 51.37
#
# Generation: 34
# 	Best - 	Fitness: 38.731, Size: 30
# 	Population - 	Average Fitness: -91.31328770166175
# 	mean = -91.31, 	median = -15.96, 	best_median = 51.37
#
# Generation: 35
# 	Best - 	Fitness: -4.823, Size: 30
# 	Population - 	Average Fitness: -99.9465507100161
# 	mean = -99.95, 	median = -63.52, 	best_median = 51.37
#
# Generation: 36
# 	Best - 	Fitness: 40.928, Size: 30
# 	Population - 	Average Fitness: -59.05259996785876
# 	mean = -59.05, 	median = -18.38, 	best_median = 51.37
#
# Generation: 37
# 	Best - 	Fitness: -17.707, Size: 30
# 	Population - 	Average Fitness: -131.26205689401377
# 	mean = -131.26, 	median = -57.16, 	best_median = 51.37
#
# Generation: 38
# 	Best - 	Fitness: 47.164, Size: 30
# 	Population - 	Average Fitness: -88.34283107033146
# 	mean = -88.34, 	median = -28.41, 	best_median = 51.37
#
# Generation: 39
# 	Best - 	Fitness: 50.871, Size: 30
# 	Population - 	Average Fitness: -97.13689601997822
# 	mean = -97.14, 	median = -41.51, 	best_median = 51.37
#
# Generation: 40
# 	Best - 	Fitness: 69.731, Size: 30
# 	Population - 	Average Fitness: -158.41526589356747
# 	mean = -158.42, 	median = -54.77, 	best_median = 51.37
#
# Generation: 41
# 	Best - 	Fitness: 34.344, Size: 30
# 	Population - 	Average Fitness: -75.62547820637906
# 	mean = -75.63, 	median = -12.30, 	best_median = 51.37
#
# Generation: 42
# 	Best - 	Fitness: 32.255, Size: 30
# 	Population - 	Average Fitness: -52.01692204143878
# 	mean = -52.02, 	median = -8.15, 	best_median = 51.37
#
# Generation: 43
# 	Best - 	Fitness: 10.869, Size: 31
# 	Population - 	Average Fitness: -89.50826357616776
# 	mean = -89.51, 	median = -29.45, 	best_median = 51.37
#
# Generation: 44
# 	Best - 	Fitness: 6.852, Size: 31
# 	Population - 	Average Fitness: -86.54152687367181
# 	mean = -86.54, 	median = -25.40, 	best_median = 51.37
#
# Generation: 45
# 	Best - 	Fitness: -29.510, Size: 30
# 	Population - 	Average Fitness: -103.88448539260014
# 	mean = -103.88, 	median = -72.38, 	best_median = 51.37
#
# Generation: 46
# 	Best - 	Fitness: 65.125, Size: 29
# 	Population - 	Average Fitness: -71.45685200340785
# 	mean = -71.46, 	median = -12.48, 	best_median = 51.37
#
# Generation: 47
# 	Best - 	Fitness: -13.326, Size: 29
# 	Population - 	Average Fitness: -128.31687347361017
# 	mean = -128.32, 	median = -62.43, 	best_median = 51.37
#
# Generation: 48
# 	Best - 	Fitness: 2.372, Size: 29
# 	Population - 	Average Fitness: -97.06945601509324
# 	mean = -97.07, 	median = -51.11, 	best_median = 51.37
#
# Generation: 49
# 	Best - 	Fitness: 13.392, Size: 29
# 	Population - 	Average Fitness: -90.74000841001221
# 	mean = -90.74, 	median = -21.58, 	best_median = 51.37
#
# Generation: 50
# 	Best - 	Fitness: -18.393, Size: 28
# 	Population - 	Average Fitness: -122.45954135829145
# 	mean = -122.46, 	median = -53.69, 	best_median = 51.37
#
# Generation: 1
# 	Best - 	Fitness: -28.124, Size: 22
# 	Population - 	Average Fitness: -196.26911140637617
# 	mean = -196.27, 	median = -129.02, 	best_median = -129.02
#
# Generation: 2
# 	Best - 	Fitness: -81.549, Size: 12
# 	Population - 	Average Fitness: -229.5110247701441
# 	mean = -229.51, 	median = -168.79, 	best_median = -129.02
#
# Generation: 3
# 	Best - 	Fitness: -59.827, Size: 23
# 	Population - 	Average Fitness: -169.3098388230458
# 	mean = -169.31, 	median = -115.93, 	best_median = -115.93
#
# Generation: 4
# 	Best - 	Fitness: -50.805, Size: 15
# 	Population - 	Average Fitness: -182.2804726592187
# 	mean = -182.28, 	median = -128.38, 	best_median = -115.93
#
# Generation: 5
# 	Best - 	Fitness: -19.137, Size: 20
# 	Population - 	Average Fitness: -169.8019972962773
# 	mean = -169.80, 	median = -107.57, 	best_median = -107.57
#
# Generation: 6
# 	Best - 	Fitness: 0.018, Size: 25
# 	Population - 	Average Fitness: -171.41221077518105
# 	mean = -171.41, 	median = -81.55, 	best_median = -81.55
#
# Generation: 7
# 	Best - 	Fitness: -12.731, Size: 15
# 	Population - 	Average Fitness: -143.42090607614952
# 	mean = -143.42, 	median = -80.35, 	best_median = -80.35
#
# Generation: 8
# 	Best - 	Fitness: 22.867, Size: 24
# 	Population - 	Average Fitness: -125.68592324090308
# 	mean = -125.69, 	median = -72.97, 	best_median = -72.97
#
# Generation: 9
# 	Best - 	Fitness: 50.441, Size: 25
# 	Population - 	Average Fitness: -85.77947244448919
# 	mean = -85.78, 	median = -28.55, 	best_median = -28.55
#
# Generation: 10
# 	Best - 	Fitness: -11.135, Size: 25
# 	Population - 	Average Fitness: -103.94364269780628
# 	mean = -103.94, 	median = -52.16, 	best_median = -28.55
#
# Generation: 11
# 	Best - 	Fitness: -5.496, Size: 26
# 	Population - 	Average Fitness: -126.6551034081517
# 	mean = -126.66, 	median = -60.73, 	best_median = -28.55
#
# Generation: 12
# 	Best - 	Fitness: 98.333, Size: 18
# 	Population - 	Average Fitness: -91.97123006090646
# 	mean = -91.97, 	median = -10.60, 	best_median = -10.60
#
# Generation: 13
# 	Best - 	Fitness: 33.237, Size: 25
# 	Population - 	Average Fitness: -123.7556447679119
# 	mean = -123.76, 	median = -26.75, 	best_median = -10.60
#
# Generation: 14
# 	Best - 	Fitness: 23.751, Size: 27
# 	Population - 	Average Fitness: -108.57365110266522
# 	mean = -108.57, 	median = -52.04, 	best_median = -10.60
#
# Generation: 15
# 	Best - 	Fitness: 56.525, Size: 25
# 	Population - 	Average Fitness: -136.7655394875995
# 	mean = -136.77, 	median = -25.80, 	best_median = -10.60
#
# Generation: 16
# 	Best - 	Fitness: 109.759, Size: 28
# 	Population - 	Average Fitness: -24.3994250227659
# 	mean = -24.40, 	median = 17.78, 	best_median = 17.78
#
# Generation: 17
# 	Best - 	Fitness: 32.255, Size: 26
# 	Population - 	Average Fitness: -125.53187800281971
# 	mean = -125.53, 	median = -63.07, 	best_median = 17.78
#
# Generation: 18
# 	Best - 	Fitness: 134.728, Size: 25
# 	Population - 	Average Fitness: -80.38025027663363
# 	mean = -80.38, 	median = 19.14, 	best_median = 19.14
#
# Generation: 19
# 	Best - 	Fitness: 42.576, Size: 25
# 	Population - 	Average Fitness: -116.37733265404216
# 	mean = -116.38, 	median = -73.36, 	best_median = 19.14
#
# Generation: 20
# 	Best - 	Fitness: 108.015, Size: 25
# 	Population - 	Average Fitness: -54.3570667293525
# 	mean = -54.36, 	median = 1.11, 	best_median = 19.14
#
# Generation: 21
# 	Best - 	Fitness: 4.125, Size: 25
# 	Population - 	Average Fitness: -96.69294872685543
# 	mean = -96.69, 	median = -59.63, 	best_median = 19.14
#
# Generation: 22
# 	Best - 	Fitness: 70.281, Size: 25
# 	Population - 	Average Fitness: -79.47871945623393
# 	mean = -79.48, 	median = -25.94, 	best_median = 19.14
#
# Generation: 23
# 	Best - 	Fitness: 88.638, Size: 25
# 	Population - 	Average Fitness: -68.73584756100135
# 	mean = -68.74, 	median = -33.89, 	best_median = 19.14
#
# Generation: 24
# 	Best - 	Fitness: 110.839, Size: 25
# 	Population - 	Average Fitness: -63.39043363139501
# 	mean = -63.39, 	median = 5.70, 	best_median = 19.14
#
# Generation: 25
# 	Best - 	Fitness: 180.246, Size: 28
# 	Population - 	Average Fitness: 22.624796131503757
# 	mean = 22.62, 	median = 95.04, 	best_median = 95.04
#
# Generation: 26
# 	Best - 	Fitness: 61.406, Size: 25
# 	Population - 	Average Fitness: -85.24908633961432
# 	mean = -85.25, 	median = -26.01, 	best_median = 95.04
#
# Generation: 27
# 	Best - 	Fitness: 92.086, Size: 29
# 	Population - 	Average Fitness: -70.87453557244132
# 	mean = -70.87, 	median = -34.14, 	best_median = 95.04
#
# Generation: 28
# 	Best - 	Fitness: 133.003, Size: 28
# 	Population - 	Average Fitness: -20.354315390615117
# 	mean = -20.35, 	median = 42.39, 	best_median = 95.04
#
# Generation: 29
# 	Best - 	Fitness: 39.688, Size: 31
# 	Population - 	Average Fitness: -125.44149913788372
# 	mean = -125.44, 	median = -73.61, 	best_median = 95.04
#
# Generation: 30
# 	Best - 	Fitness: 46.112, Size: 28
# 	Population - 	Average Fitness: -96.47591143266494
# 	mean = -96.48, 	median = -48.29, 	best_median = 95.04
#
# Generation: 31
# 	Best - 	Fitness: 174.841, Size: 28
# 	Population - 	Average Fitness: -15.366471161291917
# 	mean = -15.37, 	median = 49.43, 	best_median = 95.04
#
# Generation: 32
# 	Best - 	Fitness: 166.906, Size: 28
# 	Population - 	Average Fitness: -30.798663904329803
# 	mean = -30.80, 	median = 73.65, 	best_median = 95.04
#
# Generation: 33
# 	Best - 	Fitness: 80.134, Size: 28
# 	Population - 	Average Fitness: -46.69627856061371
# 	mean = -46.70, 	median = 17.06, 	best_median = 95.04
#
# Generation: 34
# 	Best - 	Fitness: 166.372, Size: 28
# 	Population - 	Average Fitness: 5.268623859809559
# 	mean = 5.27, 	median = 100.04, 	best_median = 100.04
#
# Generation: 35
# 	Best - 	Fitness: 149.199, Size: 28
# 	Population - 	Average Fitness: -59.42460144981322
# 	mean = -59.42, 	median = 6.02, 	best_median = 100.04
#
# Generation: 36
# 	Best - 	Fitness: 200.310, Size: 28
# 	Population - 	Average Fitness: 4.3647446475896805
# 	mean = 4.36, 	median = 83.25, 	best_median = 100.04
#
# Generation: 37
# 	Best - 	Fitness: 75.435, Size: 31
# 	Population - 	Average Fitness: -82.4964630992517
# 	mean = -82.50, 	median = -40.02, 	best_median = 100.04
#
# Generation: 38
# 	Best - 	Fitness: 96.903, Size: 28
# 	Population - 	Average Fitness: -37.96559013008289
# 	mean = -37.97, 	median = 16.43, 	best_median = 100.04
#
# Generation: 39
# 	Best - 	Fitness: 81.830, Size: 28
# 	Population - 	Average Fitness: -95.39502425733149
# 	mean = -95.40, 	median = -42.73, 	best_median = 100.04
#
# Generation: 40
# 	Best - 	Fitness: 166.266, Size: 28
# 	Population - 	Average Fitness: -59.26769183868968
# 	mean = -59.27, 	median = -11.80, 	best_median = 100.04
#
# Generation: 41
# 	Best - 	Fitness: 197.581, Size: 31
# 	Population - 	Average Fitness: -16.51938101588751
# 	mean = -16.52, 	median = 67.51, 	best_median = 100.04
#
# Generation: 42
# 	Best - 	Fitness: 234.905, Size: 28
# 	Population - 	Average Fitness: 67.28590641834221
# 	mean = 67.29, 	median = 114.33, 	best_median = 114.33
#
# Generation: 43
# 	Best - 	Fitness: 61.751, Size: 27
# 	Population - 	Average Fitness: -82.6990285712768
# 	mean = -82.70, 	median = -25.41, 	best_median = 114.33
#
# Generation: 44
# 	Best - 	Fitness: 161.150, Size: 28
# 	Population - 	Average Fitness: -15.622814575520955
# 	mean = -15.62, 	median = 40.34, 	best_median = 114.33
#
# Generation: 45
# 	Best - 	Fitness: 137.630, Size: 30
# 	Population - 	Average Fitness: -43.342098690450676
# 	mean = -43.34, 	median = 7.94, 	best_median = 114.33
#
# Generation: 46
# 	Best - 	Fitness: 165.934, Size: 28
# 	Population - 	Average Fitness: 11.692593659712044
# 	mean = 11.69, 	median = 70.83, 	best_median = 114.33
#
# Generation: 47
# 	Best - 	Fitness: 126.367, Size: 31
# 	Population - 	Average Fitness: -53.64259171777866
# 	mean = -53.64, 	median = 9.97, 	best_median = 114.33
#
# Generation: 48
# 	Best - 	Fitness: 127.741, Size: 31
# 	Population - 	Average Fitness: -34.12665639257963
# 	mean = -34.13, 	median = 16.96, 	best_median = 114.33
#
# Generation: 49
# 	Best - 	Fitness: 185.401, Size: 29
# 	Population - 	Average Fitness: -39.72110078315908
# 	mean = -39.72, 	median = 18.53, 	best_median = 114.33
#
# Generation: 50
# 	Best - 	Fitness: 175.651, Size: 27
# 	Population - 	Average Fitness: -8.961118690031595
# 	mean = -8.96, 	median = 39.06, 	best_median = 114.33

# %% [markdown]
# # Save the Evolution

# %%
import pickle

with open('baseline.pickle', 'wb') as file:
    pickle.dump(evo, file, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Test

# %%
def get_test_score(tree):
    rewards = []

    for i in range(10):
      # get initial state
      observation = env.reset(seed=i)
      observation = observation[0]

      for _ in range(500):    
        # build up the input sample for GP
        input_sample = torch.from_numpy(observation.reshape((1,-1))).float()
        # get output (squeezing because it is encapsulated in an array)
        output = tree.get_output_pt(input_sample)
        action = torch.argmax(output)
        observation, reward, terminated, truncated, info = env.step(action.item())
        rewards.append(reward)

        output_sample = torch.from_numpy(observation.reshape((1,-1))).float()
        if (terminated or truncated):
            break

    fitness = np.mean(rewards)
    
    return fitness

best = evo.best_of_gens[-1]

print(best.get_readable_repr())
print(get_test_score(best))
# Out:
# ['sqrt(abs(x_1))', '((sqrt(abs(x_1))+(sqrt(abs(x_1))+max(log(abs(x_7)),((x_3*x_5)+x_6))))+(sin(((sqrt(abs(x_1))+x_0)-sin(x_6)))+max(x_3,x_3)))', '(max(x_7,(x_5)**2)+((log(abs(x_3))+max(sqrt(abs(log(abs(x_2)))),sqrt(abs(x_0))))+sin(cos(x_0))))', '((x_5-(sqrt(abs(x_4))-cos(sqrt(abs(sqrt(abs(x_6)))))))/sin(min(cos((cos(x_6)/sin((x_4-x_4)))),x_5)))']
# 0.29488210233603424

# %% [markdown]
# ## Make an animation
# Here the best evolved individual is selected and one episode is rendered. Make sure to save your lunar landers over time to track progress and make comparisons.

# %%
frames = []

# gist to save gif from https://gist.github.com/botforge/64cbb71780e6208172bbf03cd9293553
def save_frames_as_gif(frames, path='./', filename='evolved_lander.gif'):
  plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi=72)
  patch = plt.imshow(frames[0])
  plt.axis('off')
  def animate(i):
      patch.set_data(frames[i])
  anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
  anim.save(path + filename, writer='imagemagick', fps=60)

frames = []
fitness_function_pt(best, generation = 0, num_episodes=1, episode_duration=500, render=True, ignore_done=False)
env.close()
save_frames_as_gif(frames)

# %% [markdown]
# ## Play animation

# %% [markdown]
# <img src="evolved_lander.gif" width="750">

# %% [markdown]
# ## Optimisation
# The coefficients in the multi-tree aren't optimised. Here Q-learning (taken from https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html) is used to optimise the weights further. Incorporate coefficient optimisation in training your agent(s). Coefficient Optimisation can be expensive. Think about how often you want to optimise, when, which individuals etc.

# %%
batch_size = 128
GAMMA = 0.99

constants = best.get_subtrees_consts()

if len(constants)>0:
  optimizer = optim.AdamW(constants, lr=1e-3, amsgrad=True)

for _ in range(500):

  if len(constants)>0 and len(evo.memory)>batch_size:
    target_tree = copy.deepcopy(best)

    transitions = evo.memory.sample(batch_size)
    batch = Transition(*zip(*transitions))
    
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                        batch.next_state)), dtype=torch.bool)

    non_final_next_states = torch.cat([s for s in batch.next_state
                                               if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = best.get_output_pt(state_batch).gather(1, action_batch)
    next_state_values = torch.zeros(batch_size, dtype=torch.float)
    with torch.no_grad():
      next_state_values[non_final_mask] = target_tree.get_output_pt(non_final_next_states).max(1)[0].float()

    expected_state_action_values = (next_state_values * GAMMA) + reward_batch
    
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))
   
    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_value_(constants, 100)
    optimizer.step()

print(best.get_readable_repr())
print(get_test_score(best))

# %%
frames = []
fitness_function_pt(best, num_episodes=1, episode_duration=500, render=True, ignore_done=False)
env.close()
save_frames_as_gif(frames, filename='evolved_lander_RL.gif')

# %% [markdown]
# <img src="evolved_lander_RL.gif" width="750">
